# %%
import os
import collections
import re

# %%
FILE_PATH = '/home/junjunshi/binarylearning/bisheData/binary_result/'
corpus = []
def build_dataset(dir_path,corp):
    dir_list = os.listdir(dir_path)
    for dir in dir_list:
        file_path = dir_path+dir+'/'+'all_assemble.txt'
        with open(file_path,mode='r') as f:
            content = f.read()
            corp.append(content)
            print file_path
    print len(corp)
    return corp

corpus = build_dataset(FILE_PATH,corpus)
# Out:
# /home/junjunshi/binarylearning/bisheData/binary_result/35/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/22/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/43/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/10/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/59/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/58/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/32/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/100/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/53/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/83/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/96/all_assemble.txt
# /home/junjunshi/binarylearning/bisheData/binary_result/95/all_assemble.txt
# ...

# %%
corpus=''.join(corpus)
collections.Counter(re.split(r'',corpus))
# Out:
# Counter({'': 25982209,
#          '79A0h': 2,
#          'var_1460]': 225,
#          'var_1FCC]': 57,
#          'a2538;': 1,
#          '6020CDh': 2,
#          'var_68],': 4922,
#          'var_68];': 236,
#          '0BC8C5D2Fh': 1,
#          '"%d,%d,%d"': 2,
#          '7A50D0h': 1,
#          'ds:off_4010B0[rax*8]': 1,
#          '_Z4mathi': 2,
#          'var_40638],': 2,
#          'cs:third': 10,
#          'var_C39EC],': 3,
#          'SUSHU(int)': 2,
#          'var_2EB8]': 3,
#          '4018ACh': 1,
#          '_Z5paixuPci': 4,
#          'var_3720],': 1,
#          'm[rax*4]': 3,
#          '2F10h': 105,
#          'var_547C]': 8,
#          '1140h,': 1,
#          'var_249EE8],': 5,
#          'var_14F]': 10,
#          '602364h]': 4,
#          'var_2888],': 24,
#          'var_D6DA8]': 21,
#          '400DDCh': 6,
#          '_Z10zhengchangii;': 2,
#          '_Z3delPcii': 1,
#          'combine(char': 2,
#          'var_D70': 2,
#          '401440h': 1,
# ...
