# %%
import ass2vector
import os
import tensorflow as tf
import collections
import numpy as np
import math
from gensim.models import Word2Vec
from numpy import random

# %%
INPUT_PATH = '/home/zju/slx/binarylearning/bisheData/model_input/'

# %%
corpus =[]
corpus = ass2vector.build_dataset(INPUT_PATH,corpus)
len(corpus)
# Out:
# 42846328

# %%
count = collections.Counter(corpus)
count
# Out:
# Counter({'': 4,
#          'gai': 1,
#          'weilen': 10,
#          'dert': 3,
#          'zhsh': 3,
#          'four': 3,
#          'fout': 1,
#          'minhang': 2,
#          'const': 20437,
#          'calculate': 20,
#          'shuru': 45,
#          'list': 6,
#          'aur': 2,
#          'swap': 153,
#          'alphabetic': 2,
#          'recycle': 1,
#          'digit': 2,
#          'fistp': 1,
#          'void': 3968,
#          'rem': 2,
#          'isoushu': 1,
#          'every': 1,
#          'fanzhuan': 2,
#          'scholar': 2,
#          'pingrun': 3,
#          'juzi': 3,
#          'solution': 1,
#          'putcc': 1,
#          'chuanran': 2,
#          'stum': 17,
#          'cmp': 350338,
#          'xijun': 5,
#          'direct': 4,
#          'lian': 1,
#          'second': 18,
#          'brr': 1,
#          'huiwenshu': 5,
#          'chen': 2,
#          'xingqi': 1,
#          'chek': 1,
#          'even': 11,
#          'panbie': 1,
#          'nem': 1,
#          'neg': 2594,
#          '+': 2681182,
#          'tianji': 37,
#          'ptr': 57789,
#          'checknum': 1,
#          'setprecision': 838,
#          'cheng': 8,
#          'conduct': 1,
#          'isleapyear': 16,
#          'mem': 1,
#          'men': 8,
#          'path': 2,
#          'functio': 1,
#          'stevie': 1,
#          'k': 926,
#          'credit': 4,
#          'cdet': 1,
#          'lineset': 1,
#          'divide': 31,
#          'printv': 1,
#          'cmovge': 10,
#          'replace': 5,
#          'printa': 1,
#          'substr': 9,
#          'printc': 1,
#          'printf': 55722,
#          'counts': 3,
#          'total': 135,
#          'countt': 4,
#          'getchar': 4524,
#          'shuchu': 57,
#          'charnum': 1,
#          'dna': 1,
#          'lwr': 2,
#          'hospital': 3,
#          'hanoi': 1,
#          'init': 17,
#          'dajianfa': 1,
#          'tm': 9,
#          'call': 349641,
#          'liezuixiao': 1,
#          'xueshen': 4,
#          'calc': 26,
#          'type': 6,
#          'tell': 4,
#          'aut': 10,
#          'ishui': 1,
#          'notii': 1,
#          'th': 13,
#          'jmp': 238896,
#          'haha': 4,
#          'inttostr': 1,
#          'award': 1,
#          'xiao': 11,
#          'femalecnt': 4,
#          'bysum': 1,
#          'moin': 1,
#          'exch': 3,
#          'shoot': 1,
#          'md': 1,
#          'mf': 2,
#          'join': 2,
#          'room': 40,
#          'gpai': 1,
#          'mm': 2,
#          'ml': 1,
#          'setup': 1,
#          'mn': 1,
#          'mi': 5,
#          'mk': 6,
#          'mj': 4,
#          'fking': 1,
#          'meide': 1,
#          'my': 4,
#          'example': 2,
#          'numcheck': 1,
#          'addsd': 8396,
#          'wang': 7,
#          'derta': 8,
#          'sushu': 374,
#          'iflet': 1,
#          'forodd': 1,
#          'woman': 6,
#          'fibonacci': 4,
#          'addss': 1896,
#          'gede': 2,
#          'end': 4,
#          'eng': 2,
#          'verify': 1,
#          'iiii': 12,
#          'hou': 11,
#          'answer': 14,
#          'classify': 1,
#          'dayofm': 2,
#          'lao': 1,
#          'disassemble': 1,
#          'laf': 1,
#          'after': 11,
#          'wrong': 1,
#          'trunc': 1,
#          'zhengli': 1,
#          'chartonum': 3,
#          'types': 1,
#          'third': 12,
#          'fscan': 2,
#          'shuliang': 1,
#          'nmemb': 687,
#          'stri': 1,
#          'upside': 1,
#          'enter': 3,
#          'strc': 1,
#          'operate': 10,
#          'order': 55,
#          'wine': 5,
#          'oper': 3,
#          'gujiao': 3,
#          'over': 2,
#          'imul': 66054,
#          'xi': 4,
#          'jichuan': 1,
#          'xianshi': 4,
#          'exchange': 35,
#          'before': 9,
#          'fit': 1,
#          'fix': 1,
#          ',': 5413924,
#          'qshang': 15,
#          'fib': 13,
#          'production': 1,
#          'fig': 2,
#          'crea': 1,
#          'fim': 3,
#          'combination': 2,
#          'proce': 2,
#          'zhongliu': 4,
#          'lenth': 14,
#          'qpstr': 1,
#          'yearii': 2,
#          'unvis': 3,
#          'l': 444,
#          'findking': 1,
#          'alen': 4,
#          'averse': 1,
#          'side': 1,
#          'shirunnian': 1,
#          'series': 1,
#          'insertb': 1,
#          'xgy': 1,
#          'zhaodui': 1,
#          'zhaosushu': 1,
#          'rt': 1,
#          'ru': 3,
#          'tianjie': 4,
#          'rp': 2,
#          'rr': 8,
#          'ifprime': 2,
#          'dst': 10,
#          're': 22,
#          'tianjis': 7,
#          'changdu': 8,
#          'rn': 6,
#          'size': 2772,
#          'zuida': 4,
#          'hf': 3,
#          'breakways': 1,
#          'free': 543,
#          'factorii': 1,
#          'qword': 22224,
#          'tiao': 1,
#          'houzi': 4,
#          'leapi': 1,
#          'nta': 4,
#          'freq': 11,
#          'monkey': 15,
#          'fangda': 2,
#          'topjudge': 1,
#          'subtr': 1,
#          'dayv': 1,
#          'dayr': 3,
#          'days': 108,
#          'filter': 1,
#          'isi': 1,
#          'shusu': 2,
#          'delsp': 2,
#          'jiaogu': 37,
#          'xun': 1,
#          'miaoshu': 1,
#          'huanhang': 4,
#          'shuzhi': 1,
#          'yin': 2,
#          'grade': 4,
#          'rank': 28,
#          'hook': 1,
#          'strncpy': 120,
#          'toy': 4,
#          'isalnum': 11,
#          'checkprime': 6,
#          'xiaojie': 1,
#          'huanwei': 2,
#          'qsort': 509,
#          'tot': 26,
#          'toj': 1,
#          'isalpha': 38,
#          'tol': 1,
#          'memcmp': 2,
#          'kid': 7,
#          'inputnumbers': 1,
#          'accountdays': 2,
#          'lanjie': 4,
#          'subduction': 2,
#          'scanarray': 1,
#          'nametimes': 2,
#          'distance': 24,
#          'tree': 18,
#          'daysnotleap': 1,
#          'fsubp': 6,
#          'minus': 7,
#          'mini': 3,
#          'getarray': 4,
#          'minl': 1,
#          'minm': 1,
#          'minn': 8,
#          'ran': 1,
#          'mread': 1,
#          'minf': 1,
#          'ming': 7,
#          'maxapple': 1,
#          'longl': 1,
#          'jcount': 4,
#          'mins': 1,
#          'seek': 1,
#          'minu': 1,
#          'minv': 2,
#          'mulss': 1941,
#          'maxx': 2,
#          'jueduizhi': 4,
#          'chulie': 1,
#          '-': 318,
#          'pdhw': 1,
#          'maxj': 1,
#          'maxh': 2,
#          'maxi': 3,
#          'maxn': 10,
#          'qmg': 5,
#          'mulsd': 11741,
#          'bigprint': 1,
#          'amnt': 1,
#          'bianxu': 2,
#          'disassamble': 1,
#          'newline': 1,
#          'hui': 44,
#          'doit': 6,
#          'fstp': 29,
#          'mouth': 2,
#          'letter': 11,
#          'ostream': 129349,
#          'putout': 11,
#          'datai': 1,
#          'dol': 1,
#          'dom': 3,
#          'divsd': 8572,
#          'brackets': 1,
#          'm': 1034,
#          'highget': 1,
#          'suo': 1,
#          'points': 4,
#          'jiafa': 4,
#          'bubblesort': 10,
#          'wordlen': 1,
#          'divss': 1385,
#          'reserve': 14,
#          'd.': 5,
#          'd/': 8,
#          'd-': 3,
#          'bomb': 1,
#          'josephus': 1,
#          'prin': 5,
#          'queen': 11,
#          'd=': 373,
#          'loaddata': 1,
#          'pailie': 4,
#          'kuo': 1,
#          'palindrome': 2,
#          'layout': 1,
#          'just': 1,
#          'zhii': 2,
#          'fooiiii': 2,
#          'coutt': 5,
#          'couts': 1,
#          'biubiu': 1,
#          'putapple': 6,
#          'dn': 1,
#          'do': 2,
#          'primjud': 2,
#          'solutionnum': 2,
#          'di': 3,
#          'dg': 5,
#          'dd': 8,
#          'de': 4,
#          'stop': 2,
#          'ceil': 19,
#          'jianli': 4,
#          'ston': 1,
#          'rlti': 1,
#          'dx': 81,
#          'dy': 17,
#          'daopai': 1,
#          'dt': 9,
#          'du': 6,
#          'dr': 1,
#          'ds': 49948,
#          'dp': 61,
#          'repne': 42,
#          'bat': 1,
#          'strnu': 2,
#          'perror': 1,
#          'strre': 2,
#          'bad': 1,
#          'emp': 1,
#          'runi': 1,
#          'strnl': 1,
#          'ryear': 2,
#          'bai': 1,
#          'strncmp': 11,
#          'selectsort': 1,
#          'strcat': 267,
#          'yuesefu': 3,
#          'clen': 1,
#          'result': 98,
#          'fail': 47198,
#          'blen': 5,
#          'best': 12,
#          'ishw': 3,
#          'exponent': 1,
#          'shubingpai': 1,
#          'sortb': 1,
#          'filename': 4,
#          'qwdm': 9,
#          'xiaochu': 2,
#          'score': 7,
#          'isjishu': 1,
#          'feibonaqishulie': 1,
#          'mul': 1563,
#          'sorts': 1,
#          'ferbo': 1,
#          'nsen': 3,
#          'monthii': 2,
#          'wc': 1,
#          'wa': 1,
#          'yuanshi': 6,
#          'wu': 1,
#          'ws': 1,
#          'g\\n': 1,
#          'buzhou': 1,
#          'huanh': 1,
#          'toprint': 2,
#          'tushu': 2,
#          'cos': 768,
#          'minword': 2,
#          'opration': 1,
#          'ill': 7,
#          'cmovs': 467,
#          'newhead': 3,
#          'cmovl': 1,
#          'contribution': 1,
#          'unk': 10526,
#          'com': 37,
#          'col': 89,
#          'con': 2,
#          'and': 5234,
#          'getdif': 1,
#          'tong': 11,
#          'height': 7,
#          'factorize': 3,
#          'guil': 1,
#          'fema': 4,
#          'lunhuan': 1,
#          'puts': 11913,
#          'fri': 1,
#          'three': 3,
#          'tiny': 1,
#          'anyil': 1,
#          'ifsushu': 3,
#          'initialise': 1,
#          'basic': 51093,
#          'turntoten': 1,
#          'minaaaa': 1,
#          'puti': 3,
#          'ann': 1,
#          'atgc': 2,
#          'suan': 7,
#          'shengxu': 2,
#          'pri': 8,
#          'zuhe': 1,
#          'xxx': 1,
#          'worker': 1,
#          'search': 54,
#          'daynum': 2,
#          'fflag': 2,
#          'dota': 1,
#          'child': 26,
#          'myrank': 2,
#          'save': 1,
#          'ascmax': 1,
#          'slv': 2,
#          'n': 6383,
#          'mokey': 1,
#          'paixu': 158,
#          'applesi': 1,
#          'rema': 1,
#          'procedure': 1,
#          'canf': 1,
#          'seven': 5,
#          'cons': 1,
#          'cont': 1,
#          'conv': 2,
#          'juedui': 3,
#          'ip': 4,
#          'is': 30,
#          'ans': 205,
#          'it': 1,
#          'setin': 1,
#          'caozuo': 1,
#          'ohyeah': 1,
#          'im': 22,
#          'io': 1,
#          'in': 62,
#          'ia': 1,
#          'ic': 1,
#          'ib': 1,
#          'mouse': 1,
#          'id': 1,
#          'if': 2,
#          'opr': 1,
#          'make': 13,
#          'malecnt': 4,
#          'findknot': 1,
#          'split': 1,
#          'outtime': 3,
#          'qiuyu': 1,
#          'updown': 1,
#          'pick': 2,
#          'hang': 21,
#          'xinqi': 1,
#          'hand': 4,
#          'zhiyinshu': 2,
#          'isgraph': 3,
#          'mianji': 18,
#          'qsorta': 1,
#          'qsortb': 1,
#          'puttogether': 2,
#          'gongxian': 1,
#          'game': 3,
#          'findpair': 3,
#          'getsum': 1,
#          'thi': 2,
#          'the': 2,
#          'left': 7,
#          'bigmulti': 1,
#          'dosomething': 2,
#          'sentence': 14,
#          'photo': 1,
#          'qianshou': 3,
#          'distribute': 1,
#          'zerocol': 2,
#          'opl': 1,
#          'repick': 1,
#          'findlen': 5,
#          'yes': 9,
#          'mymin': 1,
#          'countl': 1,
#          'handshake': 1,
#          'han': 2,
#          'shumu': 1,
#          'shoui': 1,
#          'spread': 15,
#          'board': 77,
#          'zhisu': 2,
#          'has': 1,
#          'opt': 2,
#          'opp': 2,
#          'panrun': 3,
#          'shisushu': 6,
#          'survival': 1,
#          'mutiply': 1,
#          'ope': 2,
#          'getaverage': 1,
#          'birth': 2,
#          'rns': 1,
#          'vis': 10,
#          'freopen': 4,
#          'fangjungen': 1,
#          'qiumax': 2,
#          'right': 9,
#          'old': 11,
#          'deal': 19,
#          'people': 19,
#          'maxii': 3,
#          'zch': 2,
#          'maxim': 1,
#          'rever': 1,
#          'born': 3,
#          'hypot': 1,
#          'statistic': 1,
#          'rangestr': 1,
#          'doublesort': 1,
#          'tolower': 15,
#          'cnt': 52,
#          'txt': 2,
#          'hanshu': 14,
#          'trace': 1,
#          'for': 2,
#          'bottom': 1,
#          'rezero': 1,
#          'iszhishu': 2,
#          'buffer': 4,
#          'allocate': 1,
#          'fob': 1,
#          'foo': 3,
#          'hsb': 1,
#          'core': 1,
#          'plu': 4,
#          'hsa': 1,
#          'posi': 1,
#          'ascanf': 1,
#          'setnb': 399,
#          'post': 2,
#          'lianjie': 1,
#          'plusbig': 1,
#          'movenum': 1,
#          'deletes': 1,
#          'plug': 1,
#          'chuan': 2,
#          'movsd': 90783,
#          'months': 9,
#          'tshang': 7,
#          'o': 58,
#          'plus': 1,
#          'movsx': 20536,
#          'zui': 1,
#          'zuo': 14,
#          'movsq': 40,
#          'subv': 1,
#          'subs': 3,
#          'fanxu': 14,
#          'float': 932,
#          'sol': 3,
#          'son': 1,
#          'down': 8,
#          'pair': 1,
#          'ppp': 5,
#          'ppt': 1,
#          'jisuan': 15,
#          'baifang': 5,
#          'gir': 1,
#          'imim': 5,
#          'imin': 1,
#          'transform': 2,
#          'fight': 8,
#          'joseph': 3,
#          'way': 19,
#          'checkrun': 1,
#          'setnz': 3731,
#          'noshowpos': 4,
#          'head': 45,
#          'medium': 6,
#          'd\\nz': 8,
#          'form': 9,
#          'ganster': 1,
#          'converse': 2,
#          'analyse': 1,
#          'd\\ns': 8,
#          'lenofr': 4,
#          'd\\nq': 8,
#          'moveforward': 1,
#          'rowmax': 2,
#          'isit': 2,
#          'combinestr': 1,
#          'devide': 11,
#          'maximum': 4,
#          'leapyeari': 1,
#          'yueshu': 1,
#          'yuandan': 2,
#          'cunzai': 1,
#          'isin': 2,
#          'delete': 2,
#          'rnfeb': 1,
#          'exist': 1,
#          'mdays': 2,
#          'allfilled': 1,
#          'qiw': 7,
#          'check': 168,
#          'shit': 2,
#          'ni': 1,
#          'nm': 38,
#          'nn': 4,
#          'floor': 89,
#          'na': 16,
#          'nf': 5,
#          'getstr': 2,
#          'leftpos': 1,
#          'ny': 2,
#          'test': 55127,
#          'shrink': 1,
#          'node': 102,
#          'nixu': 8,
#          'findmax': 8,
#          'cor': 1,
#          'ntos': 1,
#          'hebin': 4,
#          'xiaojian': 12,
#          'squ': 1,
#          'substract': 1,
#          'discharge': 1,
#          'daysleap': 1,
#          'pseudo': 1,
#          'together': 6,
#          'time': 3,
#          'push': 64982,
#          'backward': 1,
#          'getint': 1,
#          'primei': 4,
#          'danci': 1,
#          'chain': 1,
#          '.lf\\n': 1,
#          'maopao': 4,
#          'battle': 2,
#          'shot': 1,
#          'prop': 1,
#          'row': 107,
#          'inverse': 5,
#          'zong': 1,
#          'juzheng': 1,
#          'charge': 1,
#          'isspace': 7,
#          'eliminate': 1,
#          'division': 2,
#          'string': 4,
#          'hangxiao': 1,
#          'nihao': 1,
#          'arraycout': 1,
#          'isub': 3,
#          'ma': 6,
#          'birev': 2,
#          'minute': 2,
#          'cool': 1,
#          'dil': 113,
#          'jisuanb': 1,
#          'level': 10,
#          'die': 4,
#          'rechange': 3,
#          'leave': 42741,
#          'p': 620,
#          'diy': 2,
#          'team': 7,
#          'quick': 2,
#          'div': 2395,
#          'mo': 18,
#          'dir': 4,
#          'dis': 90,
#          'upper': 2,
#          'work': 46,
#          'mdisp': 1,
#          'peek': 17,
#          'itruth': 3,
#          'addauthor': 1,
#          'printfing': 1,
#          'sign': 24,
#          'setnle': 2877,
#          'rui': 5,
#          'mgpa': 1,
#          'patient': 19,
#          'mhang': 2,
#          'bacteria': 9,
#          'baka': 1,
#          'adds': 1,
#          'appear': 1,
#          'chufa': 1,
#          'orde': 1,
#          'lefts': 1,
#          'remain': 8,
#          'addd': 1,
#          'addc': 1,
#          'mergesort': 4,
#          'fmax': 6,
#          'v': 36,
#          'yiwei': 2,
#          'pause': 1,
#          'bingren': 4,
#          'newnode': 1,
#          '[': 2560836,
#          'change': 245,
#          'boy': 59,
#          'dec': 4,
#          'shift': 13,
#          'strlw': 2,
#          'mincol': 4,
#          'mx': 26,
#          'queue': 62,
#          'whatmark': 1,
#          'hubing': 1,
#          'boo': 2,
#          'convertor': 1,
#          'turnback': 1,
#          'maxnum': 3,
#          'checkbegin': 6,
#          'judgechar': 1,
#          'ipt': 2,
#          'atoten': 1,
#          'fenjie': 40,
#          'yearday': 1,
#          'deletev': 1,
#          'prove': 2,
#          'memory': 4,
#          'swep': 1,
#          'dudu': 2,
#          'd\\n': 1737,
#          'reorder': 2,
#          'judgenum': 1,
#          'separy': 1,
#          'countnum': 2,
#          'getadd': 1,
#          'rtrt': 1,
#          'distribution': 1,
#          'maxasc': 1,
#          'duma': 3,
#          'fly': 1,
#          'numberv': 1,
#          'fuction': 2,
#          'judm': 1,
#          'cas': 1,
#          'car': 1,
#          'cap': 1,
#          'flu': 5,
#          'fooii': 1,
#          'cai': 3,
#          'cao': 2,
#          'can': 7,
#          'cal': 68,
#          'showpos': 4,
#          'trans': 41,
#          'fld': 31,
#          'fenjieyinshi': 1,
#          'stream': 53,
#          'spp': 2,
#          'fuck': 9,
#          'substring': 6,
#          'erchashu': 4,
#          'cube': 2,
#          'monthv': 1,
#          'isequal': 2,
#          'feof': 8,
#          'spe': 1,
#          'strncat': 11,
#          'fpg': 3,
#          'clearerr': 2,
#          's=': 26,
#          'daycount': 3,
#          'ping': 3,
#          'idiv': 4816,
#          'write': 4,
#          'huiwenjud': 1,
#          'pure': 6,
#          'kingmonkey': 1,
#          'saintseiya': 1,
#          'divider': 2,
#          'map': 45,
#          'product': 2,
#          'mat': 40,
#          'divi': 1,
#          'inttochr': 1,
#          'divd': 1,
#          'produce': 3,
#          'uint': 83,
#          'date': 42,
#          'zimu': 18,
#          'data': 109,
#          'grow': 4,
#          'mao': 1,
#          'man': 16,
#          'sz': 78,
#          'sy': 1,
#          'sx': 3,
#          'calday': 2,
#          'diaohuan': 2,
#          'fenfa': 3,
#          'ss': 60,
#          'sr': 7,
#          'sq': 10,
#          'sw': 4,
#          'su': 108,
#          'st': 144,
#          'q': 315,
#          'sj': 9,
#          'sh': 1,
#          'so': 2,
#          'mostbook': 1,
#          'sl': 3,
#          'sc': 6,
#          'sb': 5,
#          'sa': 7,
#          'sf': 1,
#          'sd': 2,
#          'yearv': 1,
#          'years': 2,
#          'qiwang': 36,
#          'yeari': 10,
#          'handinhand': 2,
#          'quanganran': 1,
#          'numchange': 1,
#          'jie': 4,
#          'group': 8,
#          'djt': 8,
#          'istrue': 1,
#          'jia': 4,
#          'nima': 1,
#          'colmin': 1,
#          'judgebegin': 1,
#          'mail': 3,
#          'main': 581,
#          'monkeyking': 1,
#          'getlinked': 1,
#          'killer': 3,
#          'commoninteger': 1,
#          'inits': 1,
#          'half': 1,
#          'not': 68,
#          'mlie': 2,
#          'now': 14,
#          'nop': 16303,
#          'bianli': 6,
#          'nor': 1,
#          'qt': 7,
#          'term': 1,
#          'name': 20,
#          'jiaodian': 1,
#          'printarr': 1,
#          'revers': 1,
#          'isnum': 1,
#          'maxlocate': 1,
#          'dawang': 1,
#          'h': 116,
#          'square': 10,
#          'ee': 4,
#          'ec': 1,
#          'lencount': 7,
#          'ex': 6,
#          'year': 101,
#          'girl': 37,
#          'eq': 7,
#          'er': 1,
#          'fsubrp': 1,
#          'strbigint': 1,
#          'setle': 169,
#          'space': 3,
#          'fw': 2,
#          'zuobian': 2,
#          'increase': 5,
#          'godbah': 1,
#          'checkstr': 1,
#          'ishuiwen': 6,
#          'isgoodsubstr': 1,
#          'factorsii': 1,
#          'tmpl': 8,
#          'youxiu': 2,
#          'qi': 25,
#          'ori': 3,
#          'rlt': 1,
#          'byte': 28734,
#          'xiaoshi': 8,
#          'fixed': 771,
#          'scanfing': 1,
#          'shu': 18,
#          'numf': 1,
#          'turn': 32,
#          'routey': 4,
#          'routex': 4,
#          'place': 7,
#          'islower': 12,
#          'dayofy': 1,
#          'ture': 1,
#          'isupper': 9,
#          'yue': 6,
#          'jianyan': 2,
#          'first': 46,
#          'xj': 4,
#          'info': 4,
#          'oni': 1,
#          'yearsiii': 1,
#          'xl': 2,
#          'zai': 1,
#          'xb': 10,
#          'xa': 7,
#          'xg': 2,
#          'one': 4,
#          'mingliu': 1,
#          'xx': 17,
#          'reslove': 1,
#          'carry': 1,
#          'xs': 3,
#          'array': 132,
#          'isidentifor': 1,
#          'xu': 3,
#          'yid': 1,
#          'andian': 7,
#          'weekdays': 4,
#          'msort': 1,
#          'sear': 1,
#          'fraction': 1,
#          'memo': 1,
#          'houzhui': 1,
#          'twopoint': 1,
#          'pnt': 1,
#          'msize': 7,
#          'germ': 2,
#          'short': 493537,
#          'daodan': 5,
#          'copy': 8,
#          'than': 2,
#          'firstout': 4,
#          'searchjoint': 2,
#          'r': 167,
#          'apples': 2,
#          'outcome': 4,
#          'decompose': 2,
#          'pre': 4,
#          'rowset': 1,
#          'ana': 1,
#          'pro': 4,
#          'ano': 5,
#          'delim': 27,
#          'prt': 9,
#          'divmet': 1,
#          'sar': 55880,
#          'chengfa': 1,
#          'kuso': 3,
#          'fsize': 7,
#          'oddnum': 1,
#          'take': 4,
#          'destroy': 4,
#          'noti': 1,
#          'findoutmax': 1,
#          'begin': 14,
#          'boyi': 1,
#          'multiple': 3,
#          'ulong': 28,
#          'normal': 4,
#          'paib': 1,
#          'paic': 1,
#          'dicide': 1,
#          'qishu': 1,
#          'detect': 1,
#          'putapp': 1,
#          'multiply': 9,
#          'solutionnumber': 1,
#          ']': 2560836,
#          'movss': 24483,
#          ...})

# %%
count.most_common()
# Out:
# [('$', 5795827),
#  (',', 5413924),
#  ('mov', 2765516),
#  ('+', 2681182),
#  ('[', 2560836),
#  (']', 2560836),
#  ('rbp', 2483730),
#  ('eax', 2304635),
#  ('var', 2243929),
#  ('rax', 1601814),
#  (':', 966839),
#  ('add', 650981),
#  ('loc', 649912),
#  ('rdx', 615240),
#  ('edx', 515406),
#  ('short', 493537),
#  ('cmp', 350338),
#  ('call', 349641),
#  ('<', 348489),
#  ('std', 318431),
#  ('char', 312969),
#  ('*', 296721),
#  ('lea', 276296),
#  ('cdqe', 269050),
#  ('>', 257691),
#  ('sub', 254280),
#  ('jmp', 238896),
#  ('offset', 216644),
#  ('edi', 211533),
#  ('rcx', 200621),
#  ('ecx', 188654),
#  ('shl', 187150),
#  ('movsxd', 183222),
#  ('rsi', 181411),
#  (')', 181223),
#  ('(', 181219),
#  ('esi', 135634),
#  ('ostream', 129349),
#  ('rdi', 124836),
#  ('s', 123472),
#  ('al', 117585),
#  ('rsp', 116211),
#  ('&', 115756),
#  ('jz', 115425),
#  ('traits', 101541),
#  ('operator', 100259),
#  ('movzx', 99259),
#  ('jnz', 97979),
#  ('xor', 94595),
#  ('fs', 94407),
#  ('movsd', 90783),
#  ('jge', 74922),
#  ('int', 66326),
#  ('imul', 66054),
#  ('push', 64982),
#  ('jg', 62207),
#  ('jle', 59871),
#  ('ptr', 57789),
#  ('sar', 55880),
#  ('printf', 55722),
#  ('test', 55127),
#  ('scanf', 54916),
#  ('basic', 51093),
#  ('ds', 49948),
#  ('retn', 49752),
#  ('format', 49019),
#  ('chk', 47200),
#  ('stack', 47199),
#  ('fail', 47198),
#  ('leave', 42741),
#  ('locret', 41080),
#  ('rbx', 37847),
#  ('cs', 36840),
#  ('istream', 31239),
#  ('byte', 28734),
#  ('d', 28696),
#  ('c', 25995),
#  ('movss', 24483),
#  ('pxor', 23603),
#  ('qword', 22224),
#  ('dword', 22209),
#  ('movsx', 20536),
#  ('const', 20437),
#  ('pop', 20367),
#  ('jl', 19078),
#  ('endl', 18945),
#  ('strlen', 17860),
#  ('nop', 16303),
#  ('dl', 14447),
#  ('putchar', 12119),
#  ('puts', 11913),
#  ('mulsd', 11741),
#  ('movapd', 11668),
#  ('shr', 10735),
#  ('unk', 10526),
#  ('ucomisd', 10401),
#  ('ebx', 9204),
#  ('subsd', 8708),
#  ('divsd', 8572),
#  ('addsd', 8396),
#  ('rep', 7903),
#  ('stosq', 7860),
#  ('a', 7616),
#  ('jbe', 7126),
#  ('x', 6827),
#  ('gets', 6823),
#  ('edata', 6493),
#  ('n', 6383),
#  ('js', 6162),
#  ('src', 6031),
#  ('and', 5234),
#  ('idiv', 4816),
#  ('cdq', 4787),
#  ('base', 4781),
#  ('getchar', 4524),
#  ('sqrt', 4423),
#  ('dest', 4404),
#  ('double', 4108),
#  ('void', 3968),
#  ('setz', 3901),
#  ('setnz', 3731),
#  ('i', 3357),
#  ('memset', 3321),
#  ('ios', 2994),
#  ('setnle', 2877),
#  ('long', 2855),
#  ('jb', 2834),
#  ('size', 2772),
#  ('ucomiss', 2690),
#  ('neg', 2594),
#  ('jnb', 2551),
#  ('div', 2395),
#  ('getline', 2363),
#  ('cl', 2253),
#  ('malloc', 2137),
#  ('strcmp', 2121),
#  ('strcpy', 2087),
#  ('f', 2058),
#  ('jp', 1976),
#  ('ja', 1971),
#  ('mulss', 1941),
#  ('subss', 1933),
#  ('addss', 1896),
#  ('b', 1896),
#  ('lf', 1872),
#  ('get', 1781),
#  ('d\\n', 1737),
#  ('movq', 1711),
#  ('xorpd', 1622),
#  ('mul', 1563),
#  ('asc', 1491),
#  ('j', 1445),
#  ('y', 1401),
#  ('divss', 1385),
#  ('movaps', 1231),
#  ('pow', 1083),
#  ('m', 1034),
#  ('float', 932),
#  ('k', 926),
#  ('jns', 881),
#  ('off', 845),
#  ('setprecision', 838),
#  ('fixed', 771),
#  ('num', 769),
#  ('cos', 768),
#  ('ax', 741),
#  ('cqo', 710),
#  ('nmemb', 687),
#  ('nptr', 658),
#  ('c=', 644),
#  ('p', 620),
#  ('sum', 606),
#  ('main', 581),
#  ('andpd', 564),
#  ('free', 543),
#  ('s\\n', 537),
#  ('t', 527),
#  ('qsort', 509),
#  ('compar', 504),
#  ('cmovs', 467),
#  ('str', 467),
#  ('reverse', 459),
#  ('sort', 459),
#  ('l', 444),
#  ('xorps', 438),
#  ('setl', 401),
#  ('setnb', 399),
#  ('max', 391),
#  ('sushu', 374),
#  ('d=', 373),
#  ('haystack', 372),
#  ('or', 353),
#  ('stu', 351),
#  ('temp', 344),
#  ('-', 318),
#  ('q', 315),
#  ('=', 299),
#  ('setnbe', 274),
#  ('strcat', 267),
#  ('g', 264),
#  ('len', 259),
#  ('judge', 256),
#  ('word', 251),
#  ('ii', 251),
#  ('needle', 251),
#  ('change', 245),
#  ('ld', 244),
#  ('prime', 229),
#  ('c\\n', 223),
#  ('iii', 213),
#  ('sil', 212),
#  ('ans', 205),
#  ('print', 192),
#  ('andps', 188),
#  ('atoi', 181),
#  ('setle', 169),
#  ('check', 168),
#  ('r', 167),
#  ('lf\\n', 167),
#  ('min', 162),
#  ('huiwen', 160),
#  ('paixu', 158),
#  ('setnl', 158),
#  ('swap', 153),
#  ('e', 150),
#  ('count', 149),
#  ('st', 144),
#  ('input', 137),
#  ('total', 135),
#  ('array', 132),
#  ('calloc', 129),
#  ('strncpy', 120),
#  ('h', 116),
#  ('dil', 113),
#  ('flag', 110),
#  ('w', 110),
#  ('data', 109),
#  ('z', 109),
#  ('days', 108),
#  ('su', 108),
#  ('row', 107),
#  ('student', 104),
#  ('node', 102),
#  ('year', 101),
#  ('leap', 101),
#  ('day', 99),
#  ('result', 98),
#  ('apple', 93),
#  ('dis', 90),
#  ('panduan', 90),
#  ('strstr', 90),
#  ('col', 89),
#  ('floor', 89),
#  ('fun', 89),
#  ('output', 88),
#  ('uint', 83),
#  ('creat', 82),
#  ('dx', 81),
#  ('move', 79),
#  ('sz', 78),
#  ('number', 78),
#  ('board', 77),
#  ('line', 77),
#  ('length', 76),
#  ('find', 75),
#  ('out', 73),
#  ('read', 69),
#  ('match', 69),
#  ('cal', 68),
#  ('not', 68),
#  ('tmp', 68),
#  ('movd', 66),
#  ('in', 62),
#  ('queue', 62),
#  ('dp', 61),
#  ('isprime', 61),
#  ('ss', 60),
#  ('boy', 59),
#  ('o', 58),
#  ('cmovnz', 58),
#  ('shuchu', 57),
#  ('month', 57),
#  ('tian', 57),
#  ('order', 55),
#  ('run', 54),
#  ('search', 54),
#  ('setnp', 54),
#  ('stream', 53),
#  ('combine', 53),
#  ('cnt', 52),
#  ('bubble', 51),
#  ('atof', 47),
#  ('work', 46),
#  ('first', 46),
#  ('shuru', 45),
#  ('head', 45),
#  ('map', 45),
#  ('pd', 45),
#  ('function', 45),
#  ('hui', 44),
#  ('u', 44),
#  ('person', 44),
#  ('toupper', 43),
#  ('repne', 42),
#  ('date', 42),
#  ('scasb', 42),
#  ('put', 42),
#  ('trans', 41),
#  ('area', 41),
#  ('room', 40),
#  ('movsq', 40),
#  ('fenjie', 40),
#  ('mat', 40),
#  ('compare', 40),
#  ('point', 40),
#  ('hebing', 39),
#  ('money', 39),
#  ('res', 39),
#  ('isalpha', 38),
#  ('nm', 38),
#  ('tj', 38),
#  ('ld=', 38),
#  ('tianji', 37),
#  ('jiaogu', 37),
#  ('com', 37),
#  ('girl', 37),
#  ('runnian', 37),
#  ('matrix', 37),
#  ('qiwang', 36),
#  ('an', 36),
#  ('v', 36),
#  ('dijitian', 36),
#  ('la', 36),
#  ('exchange', 35),
#  ('qw', 35),
#  ('power', 34),
#  ('female', 34),
#  ('mon', 33),
#  ('zhishu', 33),
#  ('func', 32),
#  ('turn', 32),
#  ('exit', 32),
#  ('status', 32),
#  ('times', 32),
#  ('divide', 31),
#  ('fld', 31),
#  ('scan', 31),
#  ('is', 30),
#  ('male', 30),
#  ('log', 30),
#  ('fmod', 30),
#  ('strchr', 30),
#  ('fstp', 29),
#  ('pai', 29),
#  ('del', 29),
#  ('insert', 29),
#  ('memcpy', 29),
#  ('rank', 28),
#  ('ulong', 28),
#  ('f\\n', 28),
#  ('sen', 28),
#  ('delim', 27),
#  ('aa', 27),
#  ('create', 27),
#  ('arrange', 27),
#  ('strtok', 27),
#  ('calc', 26),
#  ('tot', 26),
#  ('child', 26),
#  ('mx', 26),
#  ('s=', 26),
#  ('solve', 25),
#  ('win', 25),
#  ('lb', 25),
#  ('qq', 25),
#  ('qi', 25),
#  ('distance', 24),
#  ('sign', 24),
#  ('to', 24),
#  ('convert', 24),
#  ('state', 24),
#  ('ioinit', 23),
#  ('shuzu', 23),
#  ('factor', 23),
#  ('he', 23),
#  ('re', 22),
#  ('im', 22),
#  ('up', 22),
#  ('ji', 22),
#  ('tem', 22),
#  ('king', 22),
#  ('chang', 22),
#  ('stud', 22),
#  ('px', 22),
#  ('hang', 21),
#  ('of', 21),
#  ('arr', 21),
#  ('arg', 21),
#  ('bb', 21),
#  ('calculate', 20),
#  ('name', 20),
#  ('pat', 20),
#  ('aaa', 20),
#  ('grids', 20),
#  ('hw', 20),
#  ('ceil', 19),
#  ('deal', 19),
#  ('people', 19),
#  ('way', 19),
#  ('pos', 19),
#  ('jishu', 19),
#  ('ys', 19),
#  ('lie', 19),
#  ('ignore', 19),
#  ('patient', 19),
#  ('zhi', 19),
#  ('zh', 19),
#  ('from', 19),
#  ('ren', 19),
#  ('zfc', 19),
#  ('ch', 19),
#  ('know', 19),
#  ('second', 18),
#  ('tree', 18),
#  ('mianji', 18),
#  ('mo', 18),
#  ('zimu', 18),
#  ('qj', 18),
#  ('exam', 18),
#  ('pan', 18),
#  ('abs', 18),
#  ('jilu', 18),
#  ('shu', 18),
#  ('shang', 18),
#  ('dy', 17),
#  ('peek', 17),
#  ('xx', 17),
#  ('init', 17),
#  ('link', 17),
#  ('use', 17),
#  ('fen', 17),
#  ('counter', 17),
#  ('merge', 17),
#  ('rev', 17),
#  ('rec', 17),
#  ('stum', 17),
#  ('ld\\n', 17),
#  ('juli', 17),
#  ('isrunnian', 17),
#  ('words', 17),
#  ('book', 17),
#  ('isleapyear', 16),
#  ('na', 16),
#  ('man', 16),
#  ('comp', 16),
#  ('txia', 16),
#  ('start', 16),
#  ('all', 16),
#  ('fy', 16),
#  ('jiaohuan', 16),
#  ('dui', 16),
#  ('pp', 16),
#  ('zhao', 16),
#  ('qshang', 15),
#  ('spread', 15),
#  ('schsum', 15),
#  ('jh', 15),
#  ('juzhen', 15),
#  ('issushu', 15),
#  ('dfs', 15),
#  ('sex', 15),
#  ('fang', 15),
#  ('pa', 15),
#  ('cut', 15),
#  ('big', 15),
#  ('jisuan', 15),
#  ('bl', 15),
#  ('monkey', 15),
#  ('tolower', 15),
#  ('ci', 15),
#  ('answer', 14),
#  ('lenth', 14),
#  ('reserve', 14),
#  ('sentence', 14),
#  ('zuo', 14),
#  ('fanxu', 14),
#  ('now', 14),
#  ('begin', 14),
#  ('fan', 14),
#  ('guiling', 14),
#  ('go', 14),
#  ('hanshu', 14),
#  ('course', 14),
#  ('fbnq', 14),
#  ('fib', 13),
#  ('make', 13),
#  ('shift', 13),
#  ('ways', 13),
#  ('week', 13),
#  ('th', 13),
#  ('lc', 13),
#  ('tran', 13),
#  ('fild', 13),
#  ('iiii', 12),
#  ('third', 12),
#  ('best', 12),
#  ('xiaojian', 12),
#  ('islower', 12),
#  ('digui', 12),
#  ('same', 12),
#  ('bac', 12),
#  ('jian', 12),
#  ('tt', 12),
#  ('zero', 12),
#  ('kk', 12),
#  ('single', 12),
#  ('cha', 12),
#  ("'", 12),
#  ('cc', 12),
#  ('paidui', 12),
#  ('sscanf', 12),
#  ('indata', 12),
#  ('even', 11),
#  ('hou', 11),
#  ('after', 11),
#  ('freq', 11),
#  ('isalnum', 11),
#  ('letter', 11),
#  ('putout', 11),
#  ('queen', 11),
#  ('strncmp', 11),
#  ('tong', 11),
#  ('old', 11),
#  ('devide', 11),
#  ('strncat', 11),
#  ('jd', 11),
#  ('fgets', 11),
#  ('op', 11),
#  ('ansn', 11),
#  ('dist', 11),
#  ('sch', 11),
#  ('qiwange', 11),
#  ('xiao', 11),
#  ('process', 11),
#  ('ct', 11),
#  ('tbyte', 11),
#  ('huan', 11),
#  ('inv', 11),
#  ('weilen', 10),
#  ('cmovge', 10),
#  ('aut', 10),
#  ('operate', 10),
#  ('dst', 10),
#  ('maxn', 10),
#  ('level', 10),
#  ('fanzhi', 10),
#  ('sq', 10),
#  ('yeari', 10),
#  ('square', 10),
#  ('xb', 10),
#  ('show', 10),
#  ('ddd', 10),
#  ('strin', 10),
#  ('ord', 10),
#  ('yushu', 10),
#  ('sprintf', 10),
#  ('abc', 10),
#  ('clear', 10),
#  ('linelen', 10),
#  ('gap', 10),
#  ('fei', 10),
#  ('bubblesort', 10),
#  ('high', 10),
#  ('iiiii', 10),
#  ('beichu', 10),
#  ('cwde', 10),
#  ('cache', 10),
#  ('vis', 10),
#  ('before', 9),
#  ('yinshu', 9),
#  ('dt', 9),
#  ('qwdm', 9),
#  ('yes', 9),
#  ('substr', 9),
#  ('right', 9),
#  ('months', 9),
#  ('multiply', 9),
#  ('form', 9),
#  ('bacteria', 9),
#  ('fuck', 9),
#  ('sj', 9),
#  ('isupper', 9),
#  ('prt', 9),
#  ('poi', 9),
#  ('bijiao', 9),
#  ('cx', 9),
#  ('ou', 9),
#  ('low', 9),
#  ('ab', 9),
#  ('tm', 9),
#  ('yaolen', 9),
#  ('fj', 9),
#  ('yu', 9),
#  ('common', 9),
#  ('seq', 9),
#  ('flight', 9),
#  ('back', 9),
#  ('step', 9),
#  ('moun', 9),
#  ('tjdm', 9),
#  ('va', 9),
#  ('matrixx', 9),
#  ('val', 9),
#  ('record', 9),
#  ('cheng', 8),
#  ('men', 8),
#  ('derta', 8),
#  ('group', 8),
#  ('rr', 8),
#  ('changdu', 8),
#  ('minn', 8),
#  ('d/', 8),
#  ('dd', 8),
#  ('down', 8),
#  ('fight', 8),
#  ('d\\nz', 8),
#  ('d\\ns', 8),
#  ('d\\nq', 8),
#  ('nixu', 8),
#  ('findmax', 8),
#  ('feof', 8),
#  ('djt', 8),
#  ('qx', 8),
#  ('tmpl', 8),
#  ('xiaoshi', 8),
#  ('copy', 8),
#  ('pri', 8),
#  ('ff', 8),
#  ('cmovle', 8),
#  ('two', 8),
#  ('duqu', 8),
#  ('remain', 8),
#  ('cen', 8),
#  ('qiwangs', 8),
#  ('kh', 8),
#  ('cell', 8),
#  ('circle', 8),
#  ('pe', 8),
#  ('zhuan', 8),
#  ('bn', 8),
#  ('odd', 8),
#  ('pipei', 8),
#  ('chu', 8),
#  ('auth', 8),
#  ('bec', 8),
#  ('ave', 8),
#  ('wei', 8),
#  ('replacement', 8),
#  ('display', 8),
#  ('wang', 7),
#  ('tianjis', 7),
#  ('andian', 7),
#  ('minus', 7),
#  ('ming', 7),
#  ('wusi', 7),
#  ('score', 7),
#  ('ill', 7),
#  ('height', 7),
#  ('suan', 7),
#  ('kid', 7),
#  ('fucomip', 7),
#  ('left', 7),
#  ('tshang', 7),
#  ('qiw', 7),
#  ('isspace', 7),
#  ('team', 7),
#  ('can', 7),
#  ('sr', 7),
#  ('sa', 7),
#  ('lencount', 7),
#  ('eq', 7),
#  ('place', 7),
#  ('xa', 7),
#  ('msize', 7),
#  ('fsize', 7),
#  ('average', 7),
#  ('checki', 7),
#  ('mark', 7),
#  ('putin', 7),
#  ('coutnoneg', 7),
#  ('sca', 7),
#  ('thorse', 7),
#  ('qhorse', 7),
#  ('known', 7),
#  ('fb', 7),
#  ('connect', 7),
#  ('countday', 7),
#  ('nian', 7),
#  ('sta', 7),
#  ('xibu', 7),
#  ('fangcha', 7),
#  ('set', 7),
#  ('used', 7),
#  ('yuan', 7),
#  ('ppow', 7),
#  ('per', 7),
#  ('lans', 7),
#  ('ctt', 7),
#  ('shanchu', 7),
#  ('chr', 7),
#  ('leapyear', 7),
#  ('trail', 7),
#  ('li', 7),
#  ('choose', 7),
#  ('putstr', 7),
#  ('qt', 7),
#  ('peidui', 7),
#  ('inda', 7),
#  ('fact', 7),
#  ('tianshu', 7),
#  ('fre', 7),
#  ('empty', 7),
#  ('zheng', 7),
#  ('type', 6),
#  ('ma', 6),
#  ('mk', 6),
#  ('rn', 6),
#  ('checkprime', 6),
#  ('fsubp', 6),
#  ('doit', 6),
#  ('tries', 6),
#  ('putapple', 6),
#  ('du', 6),
#  ('fscanf', 6),
#  ('yuanshi', 6),
#  ('medium', 6),
#  ('together', 6),
#  ('mizhi', 6),
#  ('fmax', 6),
#  ('checkbegin', 6),
#  ('substring', 6),
#  ('pure', 6),
#  ('sc', 6),
#  ('ex', 6),
#  ('ishuiwen', 6),
#  ('yue', 6),
#  ('zhuanhuan', 6),
#  ('jiange', 6),
#  ('oushu', 6),
#  ('numfemale', 6),
#  ('jw', 6),
#  ('assertions', 6),
#  ('pay', 6),
#  ('ok', 6),
#  ('ai', 6),
#  ('tr', 6),
#  ('woman', 6),
#  ('list', 6),
#  ('sang', 6),
#  ('shulie', 6),
#  ('method', 6),
#  ('numb', 6),
#  ('fff', 6),
#  ('feibo', 6),
#  ('leg', 6),
#  ('pg', 6),
#  ('look', 6),
#  ('leapy', 6),
#  ('fflush', 6),
#  ('shisushu', 6),
#  ('bo', 6),
#  ('fibo', 6),
#  ('.f', 6),
#  ('fldz', 6),
#  ('qian', 6),
#  ('zl', 6),
#  ('boolean', 6),
#  ('sgn', 6),
#  ('tar', 6),
#  ('faddp', 6),
#  ('tag', 6),
#  ('xqj', 6),
#  ('ln', 6),
#  ('daoxu', 6),
#  ('zuozhe', 6),
#  ('varieties', 6),
#  ('angle', 6),
#  ('key', 6),
#  ('qxia', 6),
#  ('ysf', 6),
#  ('ppatient', 6),
#  ('cntf', 6),
#  ('cifang', 6),
#  ('bianli', 6),
#  ('hb', 6),
#  ('limit', 6),
#  ('precision', 6),
#  ('pr', 6),
#  ('xijun', 5),
#  ('huiwenshu', 5),
#  ('children', 5),
#  ('replace', 5),
#  ('mi', 5),
#  ('wine', 5),
#  ('fac', 5),
#  ('d.', 5),
#  ('prin', 5),
#  ('coutt', 5),
#  ('dg', 5),
#  ('next', 5),
#  ('blen', 5),
#  ('seven', 5),
#  ('ppp', 5),
#  ('baifang', 5),
#  ('imim', 5),
#  ('nf', 5),
#  ('inverse', 5),
#  ('flu', 5),
#  ('sb', 5),
#  ('increase', 5),
#  ('daodan', 5),
#  ('ano', 5),
#  ('germs', 5),
#  ('leapyearmonth', 5),
#  ('ju', 5),
#  ('former', 5),
#  ('author', 5),
#  ('istore', 5),
#  ('yeariiiii', 5),
#  ('speed', 5),
#  ('leta', 5),
#  ('letb', 5),
#  ('sums', 5),
#  ('jud', 5),
#  ('fuhao', 5),
#  ('tp', 5),
#  ('decide', 5),
#  ('qmg', 5),
#  ('full', 5),
#  ('hour', 5),
#  ('maxright', 5),
#  ('yy', 5),
#  ('findday', 5),
#  ('operation', 5),
#  ('banji', 5),
#  ('buf', 5),
#  ('remove', 5),
#  ('swi', 5),
#  ('origin', 5),
#  ('findlen', 5),
#  ('outputdata', 5),
#  ('monthday', 5),
#  ('rui', 5),
#  ('ba', 5),
#  ('maxlen', 5),
#  ('breed', 5),
#  ('bracket', 5),
#  ('lena', 5),
#  ('gg', 5),
#  ('nummale', 5),
#  ('bknown', 5),
#  ('judgeyear', 5),
#  ('need', 5),
#  ('sig', 5),
#  ('dao', 5),
#  ('dat', 5),
#  ('route', 5),
#  ('final', 5),
#  ('lastnumber', 5),
#  ('rearrange', 5),
#  ('gram', 5),
#  ('qh', 5),
#  ('equal', 5),
#  ('value', 5),
#  ('vb', 5),
#  ('cntm', 5),
#  ('sequence', 5),
#  ('minleft', 5),
#  ('pool', 5),
#  ('hh', 5),
#  ('commonyearmonth', 5),
#  ('stat', 5),
#  ('', 4),
#  ('direct', 4),
#  ('credit', 4),
#  ('countt', 4),
#  ('xueshen', 4),
#  ('tell', 4),
#  ('haha', 4),
#  ('femalecnt', 4),
#  ('mj', 4),
#  ('my', 4),
#  ('fibonacci', 4),
#  ('end', 4),
#  ('xj', 4),
#  ('zhongliu', 4),
#  ('alen', 4),
#  ('tianjie', 4),
#  ('zuida', 4),
#  ('houzi', 4),
#  ('nta', 4),
#  ('huanhang', 4),
#  ('toy', 4),
#  ('lanjie', 4),
#  ('getarray', 4),
#  ('jcount', 4),
#  ('jueduizhi', 4),
#  ('points', 4),
#  ('jiafa', 4),
#  ('de', 4),
#  ('filename', 4),
#  ('outcome', 4),
#  ('pre', 4),
#  ('fema', 4),
#  ('pro', 4),
#  ('ip', 4),
#  ('malecnt', 4),
#  ('hand', 4),
#  ('chengji', 4),
#  ('freopen', 4),
#  ('plu', 4),
#  ('noshowpos', 4),
#  ('lenofr', 4),
#  ('maximum', 4),
#  ('nn', 4),
#  ('hebin', 4),
#  ('primei', 4),
#  ('maopao', 4),
#  ('string', 4),
#  ('die', 4),
#  ('dir', 4),
#  ('mergesort', 4),
#  ('mincol', 4),
#  ('memory', 4),
#  ('showpos', 4),
#  ('erchashu', 4),
#  ('write', 4),
#  ('grow', 4),
#  ('sw', 4),
#  ('jie', 4),
#  ('jia', 4),
#  ('ee', 4),
#  ('routey', 4),
#  ('routex', 4),
#  ('xi', 4),
#  ('one', 4),
#  ('weekdays', 4),
#  ('firstout', 4),
#  ('outd', 4),
#  ('arrayv', 4),
#  ('take', 4),
#  ('destroy', 4),
#  ('normal', 4),
#  ('buffer', 4),
#  ('ccount', 4),
#  ('invert', 4),
#  ('geshu', 4),
#  ('modes', 4),
#  ('detc', 4),
#  ('lon', 4),
#  ('ffabs', 4),
#  ('bucket', 4),
#  ('cbw', 4),
#  ('legal', 4),
#  ('fab', 4),
#  ('small', 4),
#  ('tel', 4),
#  ('pailie', 4),
#  ('palin', 4),
#  ('amount', 4),
#  ('select', 4),
#  ('vi', 4),
#  ('dec', 4),
#  ('fr', 4),
#  ('fa', 4),
#  ('numa', 4),
#  ('fi', 4),
#  ('fk', 4),
#  ('grade', 4),
#  ('shuzi', 4),
#  ('reduce', 4),
#  ('nowlen', 4),
#  ('longtime', 4),
#  ('guess', 4),
#  ('ispr', 4),
#  ('highestpos', 4),
#  ('quicksort', 4),
#  ('setp', 4),
#  ('play', 4),
#  ('charu', 4),
#  ('exp', 4),
#  ('femail', 4),
#  ('printarray', 4),
#  ('totalmember', 4),
#  ('po', 4),
#  ('kuohao', 4),
#  ('jianli', 4),
#  ('oho', 4),
#  ('cul', 4),
#  ('couple', 4),
#  ...]

# %%
len(count)
# Out:
# 2651

# %%
count = [['UNK',-1]]
count.extend(collections.Counter(corpus).most_common())
count
# Out:
# [['UNK', -1],
#  ('$', 5795827),
#  (',', 5413924),
#  ('mov', 2765516),
#  ('+', 2681182),
#  ('[', 2560836),
#  (']', 2560836),
#  ('rbp', 2483730),
#  ('eax', 2304635),
#  ('var', 2243929),
#  ('rax', 1601814),
#  (':', 966839),
#  ('add', 650981),
#  ('loc', 649912),
#  ('rdx', 615240),
#  ('edx', 515406),
#  ('short', 493537),
#  ('cmp', 350338),
#  ('call', 349641),
#  ('<', 348489),
#  ('std', 318431),
#  ('char', 312969),
#  ('*', 296721),
#  ('lea', 276296),
#  ('cdqe', 269050),
#  ('>', 257691),
#  ('sub', 254280),
#  ('jmp', 238896),
#  ('offset', 216644),
#  ('edi', 211533),
#  ('rcx', 200621),
#  ('ecx', 188654),
#  ('shl', 187150),
#  ('movsxd', 183222),
#  ('rsi', 181411),
#  (')', 181223),
#  ('(', 181219),
#  ('esi', 135634),
#  ('ostream', 129349),
#  ('rdi', 124836),
#  ('s', 123472),
#  ('al', 117585),
#  ('rsp', 116211),
#  ('&', 115756),
#  ('jz', 115425),
#  ('traits', 101541),
#  ('operator', 100259),
#  ('movzx', 99259),
#  ('jnz', 97979),
#  ('xor', 94595),
#  ('fs', 94407),
#  ('movsd', 90783),
#  ('jge', 74922),
#  ('int', 66326),
#  ('imul', 66054),
#  ('push', 64982),
#  ('jg', 62207),
#  ('jle', 59871),
#  ('ptr', 57789),
#  ('sar', 55880),
#  ('printf', 55722),
#  ('test', 55127),
#  ('scanf', 54916),
#  ('basic', 51093),
#  ('ds', 49948),
#  ('retn', 49752),
#  ('format', 49019),
#  ('chk', 47200),
#  ('stack', 47199),
#  ('fail', 47198),
#  ('leave', 42741),
#  ('locret', 41080),
#  ('rbx', 37847),
#  ('cs', 36840),
#  ('istream', 31239),
#  ('byte', 28734),
#  ('d', 28696),
#  ('c', 25995),
#  ('movss', 24483),
#  ('pxor', 23603),
#  ('qword', 22224),
#  ('dword', 22209),
#  ('movsx', 20536),
#  ('const', 20437),
#  ('pop', 20367),
#  ('jl', 19078),
#  ('endl', 18945),
#  ('strlen', 17860),
#  ('nop', 16303),
#  ('dl', 14447),
#  ('putchar', 12119),
#  ('puts', 11913),
#  ('mulsd', 11741),
#  ('movapd', 11668),
#  ('shr', 10735),
#  ('unk', 10526),
#  ('ucomisd', 10401),
#  ('ebx', 9204),
#  ('subsd', 8708),
#  ('divsd', 8572),
#  ('addsd', 8396),
#  ('rep', 7903),
#  ('stosq', 7860),
#  ('a', 7616),
#  ('jbe', 7126),
#  ('x', 6827),
#  ('gets', 6823),
#  ('edata', 6493),
#  ('n', 6383),
#  ('js', 6162),
#  ('src', 6031),
#  ('and', 5234),
#  ('idiv', 4816),
#  ('cdq', 4787),
#  ('base', 4781),
#  ('getchar', 4524),
#  ('sqrt', 4423),
#  ('dest', 4404),
#  ('double', 4108),
#  ('void', 3968),
#  ('setz', 3901),
#  ('setnz', 3731),
#  ('i', 3357),
#  ('memset', 3321),
#  ('ios', 2994),
#  ('setnle', 2877),
#  ('long', 2855),
#  ('jb', 2834),
#  ('size', 2772),
#  ('ucomiss', 2690),
#  ('neg', 2594),
#  ('jnb', 2551),
#  ('div', 2395),
#  ('getline', 2363),
#  ('cl', 2253),
#  ('malloc', 2137),
#  ('strcmp', 2121),
#  ('strcpy', 2087),
#  ('f', 2058),
#  ('jp', 1976),
#  ('ja', 1971),
#  ('mulss', 1941),
#  ('subss', 1933),
#  ('addss', 1896),
#  ('b', 1896),
#  ('lf', 1872),
#  ('get', 1781),
#  ('d\\n', 1737),
#  ('movq', 1711),
#  ('xorpd', 1622),
#  ('mul', 1563),
#  ('asc', 1491),
#  ('j', 1445),
#  ('y', 1401),
#  ('divss', 1385),
#  ('movaps', 1231),
#  ('pow', 1083),
#  ('m', 1034),
#  ('float', 932),
#  ('k', 926),
#  ('jns', 881),
#  ('off', 845),
#  ('setprecision', 838),
#  ('fixed', 771),
#  ('num', 769),
#  ('cos', 768),
#  ('ax', 741),
#  ('cqo', 710),
#  ('nmemb', 687),
#  ('nptr', 658),
#  ('c=', 644),
#  ('p', 620),
#  ('sum', 606),
#  ('main', 581),
#  ('andpd', 564),
#  ('free', 543),
#  ('s\\n', 537),
#  ('t', 527),
#  ('qsort', 509),
#  ('compar', 504),
#  ('cmovs', 467),
#  ('str', 467),
#  ('reverse', 459),
#  ('sort', 459),
#  ('l', 444),
#  ('xorps', 438),
#  ('setl', 401),
#  ('setnb', 399),
#  ('max', 391),
#  ('sushu', 374),
#  ('d=', 373),
#  ('haystack', 372),
#  ('or', 353),
#  ('stu', 351),
#  ('temp', 344),
#  ('-', 318),
#  ('q', 315),
#  ('=', 299),
#  ('setnbe', 274),
#  ('strcat', 267),
#  ('g', 264),
#  ('len', 259),
#  ('judge', 256),
#  ('word', 251),
#  ('ii', 251),
#  ('needle', 251),
#  ('change', 245),
#  ('ld', 244),
#  ('prime', 229),
#  ('c\\n', 223),
#  ('iii', 213),
#  ('sil', 212),
#  ('ans', 205),
#  ('print', 192),
#  ('andps', 188),
#  ('atoi', 181),
#  ('setle', 169),
#  ('check', 168),
#  ('r', 167),
#  ('lf\\n', 167),
#  ('min', 162),
#  ('huiwen', 160),
#  ('paixu', 158),
#  ('setnl', 158),
#  ('swap', 153),
#  ('e', 150),
#  ('count', 149),
#  ('st', 144),
#  ('input', 137),
#  ('total', 135),
#  ('array', 132),
#  ('calloc', 129),
#  ('strncpy', 120),
#  ('h', 116),
#  ('dil', 113),
#  ('flag', 110),
#  ('w', 110),
#  ('data', 109),
#  ('z', 109),
#  ('days', 108),
#  ('su', 108),
#  ('row', 107),
#  ('student', 104),
#  ('node', 102),
#  ('year', 101),
#  ('leap', 101),
#  ('day', 99),
#  ('result', 98),
#  ('apple', 93),
#  ('dis', 90),
#  ('panduan', 90),
#  ('strstr', 90),
#  ('col', 89),
#  ('floor', 89),
#  ('fun', 89),
#  ('output', 88),
#  ('uint', 83),
#  ('creat', 82),
#  ('dx', 81),
#  ('move', 79),
#  ('sz', 78),
#  ('number', 78),
#  ('board', 77),
#  ('line', 77),
#  ('length', 76),
#  ('find', 75),
#  ('out', 73),
#  ('read', 69),
#  ('match', 69),
#  ('cal', 68),
#  ('not', 68),
#  ('tmp', 68),
#  ('movd', 66),
#  ('in', 62),
#  ('queue', 62),
#  ('dp', 61),
#  ('isprime', 61),
#  ('ss', 60),
#  ('boy', 59),
#  ('o', 58),
#  ('cmovnz', 58),
#  ('shuchu', 57),
#  ('month', 57),
#  ('tian', 57),
#  ('order', 55),
#  ('run', 54),
#  ('search', 54),
#  ('setnp', 54),
#  ('stream', 53),
#  ('combine', 53),
#  ('cnt', 52),
#  ('bubble', 51),
#  ('atof', 47),
#  ('work', 46),
#  ('first', 46),
#  ('shuru', 45),
#  ('head', 45),
#  ('map', 45),
#  ('pd', 45),
#  ('function', 45),
#  ('hui', 44),
#  ('u', 44),
#  ('person', 44),
#  ('toupper', 43),
#  ('repne', 42),
#  ('date', 42),
#  ('scasb', 42),
#  ('put', 42),
#  ('trans', 41),
#  ('area', 41),
#  ('room', 40),
#  ('movsq', 40),
#  ('fenjie', 40),
#  ('mat', 40),
#  ('compare', 40),
#  ('point', 40),
#  ('hebing', 39),
#  ('money', 39),
#  ('res', 39),
#  ('isalpha', 38),
#  ('nm', 38),
#  ('tj', 38),
#  ('ld=', 38),
#  ('tianji', 37),
#  ('jiaogu', 37),
#  ('com', 37),
#  ('girl', 37),
#  ('runnian', 37),
#  ('matrix', 37),
#  ('qiwang', 36),
#  ('an', 36),
#  ('v', 36),
#  ('dijitian', 36),
#  ('la', 36),
#  ('exchange', 35),
#  ('qw', 35),
#  ('power', 34),
#  ('female', 34),
#  ('mon', 33),
#  ('zhishu', 33),
#  ('func', 32),
#  ('turn', 32),
#  ('exit', 32),
#  ('status', 32),
#  ('times', 32),
#  ('divide', 31),
#  ('fld', 31),
#  ('scan', 31),
#  ('is', 30),
#  ('male', 30),
#  ('log', 30),
#  ('fmod', 30),
#  ('strchr', 30),
#  ('fstp', 29),
#  ('pai', 29),
#  ('del', 29),
#  ('insert', 29),
#  ('memcpy', 29),
#  ('rank', 28),
#  ('ulong', 28),
#  ('f\\n', 28),
#  ('sen', 28),
#  ('delim', 27),
#  ('aa', 27),
#  ('create', 27),
#  ('arrange', 27),
#  ('strtok', 27),
#  ('calc', 26),
#  ('tot', 26),
#  ('child', 26),
#  ('mx', 26),
#  ('s=', 26),
#  ('solve', 25),
#  ('win', 25),
#  ('lb', 25),
#  ('qq', 25),
#  ('qi', 25),
#  ('distance', 24),
#  ('sign', 24),
#  ('to', 24),
#  ('convert', 24),
#  ('state', 24),
#  ('ioinit', 23),
#  ('shuzu', 23),
#  ('factor', 23),
#  ('he', 23),
#  ('re', 22),
#  ('im', 22),
#  ('up', 22),
#  ('ji', 22),
#  ('tem', 22),
#  ('king', 22),
#  ('chang', 22),
#  ('stud', 22),
#  ('px', 22),
#  ('hang', 21),
#  ('of', 21),
#  ('arr', 21),
#  ('arg', 21),
#  ('bb', 21),
#  ('calculate', 20),
#  ('name', 20),
#  ('pat', 20),
#  ('aaa', 20),
#  ('grids', 20),
#  ('hw', 20),
#  ('ceil', 19),
#  ('deal', 19),
#  ('people', 19),
#  ('way', 19),
#  ('pos', 19),
#  ('jishu', 19),
#  ('ys', 19),
#  ('lie', 19),
#  ('ignore', 19),
#  ('patient', 19),
#  ('zhi', 19),
#  ('zh', 19),
#  ('from', 19),
#  ('ren', 19),
#  ('zfc', 19),
#  ('ch', 19),
#  ('know', 19),
#  ('second', 18),
#  ('tree', 18),
#  ('mianji', 18),
#  ('mo', 18),
#  ('zimu', 18),
#  ('qj', 18),
#  ('exam', 18),
#  ('pan', 18),
#  ('abs', 18),
#  ('jilu', 18),
#  ('shu', 18),
#  ('shang', 18),
#  ('dy', 17),
#  ('peek', 17),
#  ('xx', 17),
#  ('init', 17),
#  ('link', 17),
#  ('use', 17),
#  ('fen', 17),
#  ('counter', 17),
#  ('merge', 17),
#  ('rev', 17),
#  ('rec', 17),
#  ('stum', 17),
#  ('ld\\n', 17),
#  ('juli', 17),
#  ('isrunnian', 17),
#  ('words', 17),
#  ('book', 17),
#  ('isleapyear', 16),
#  ('na', 16),
#  ('man', 16),
#  ('comp', 16),
#  ('txia', 16),
#  ('start', 16),
#  ('all', 16),
#  ('fy', 16),
#  ('jiaohuan', 16),
#  ('dui', 16),
#  ('pp', 16),
#  ('zhao', 16),
#  ('qshang', 15),
#  ('spread', 15),
#  ('schsum', 15),
#  ('jh', 15),
#  ('juzhen', 15),
#  ('issushu', 15),
#  ('dfs', 15),
#  ('sex', 15),
#  ('fang', 15),
#  ('pa', 15),
#  ('cut', 15),
#  ('big', 15),
#  ('jisuan', 15),
#  ('bl', 15),
#  ('monkey', 15),
#  ('tolower', 15),
#  ('ci', 15),
#  ('answer', 14),
#  ('lenth', 14),
#  ('reserve', 14),
#  ('sentence', 14),
#  ('zuo', 14),
#  ('fanxu', 14),
#  ('now', 14),
#  ('begin', 14),
#  ('fan', 14),
#  ('guiling', 14),
#  ('go', 14),
#  ('hanshu', 14),
#  ('course', 14),
#  ('fbnq', 14),
#  ('fib', 13),
#  ('make', 13),
#  ('shift', 13),
#  ('ways', 13),
#  ('week', 13),
#  ('th', 13),
#  ('lc', 13),
#  ('tran', 13),
#  ('fild', 13),
#  ('iiii', 12),
#  ('third', 12),
#  ('best', 12),
#  ('xiaojian', 12),
#  ('islower', 12),
#  ('digui', 12),
#  ('same', 12),
#  ('bac', 12),
#  ('jian', 12),
#  ('tt', 12),
#  ('zero', 12),
#  ('kk', 12),
#  ('single', 12),
#  ('cha', 12),
#  ("'", 12),
#  ('cc', 12),
#  ('paidui', 12),
#  ('sscanf', 12),
#  ('indata', 12),
#  ('even', 11),
#  ('hou', 11),
#  ('after', 11),
#  ('freq', 11),
#  ('isalnum', 11),
#  ('letter', 11),
#  ('putout', 11),
#  ('queen', 11),
#  ('strncmp', 11),
#  ('tong', 11),
#  ('old', 11),
#  ('devide', 11),
#  ('strncat', 11),
#  ('jd', 11),
#  ('fgets', 11),
#  ('op', 11),
#  ('ansn', 11),
#  ('dist', 11),
#  ('sch', 11),
#  ('qiwange', 11),
#  ('xiao', 11),
#  ('process', 11),
#  ('ct', 11),
#  ('tbyte', 11),
#  ('huan', 11),
#  ('inv', 11),
#  ('weilen', 10),
#  ('cmovge', 10),
#  ('aut', 10),
#  ('operate', 10),
#  ('dst', 10),
#  ('maxn', 10),
#  ('level', 10),
#  ('fanzhi', 10),
#  ('sq', 10),
#  ('yeari', 10),
#  ('square', 10),
#  ('xb', 10),
#  ('show', 10),
#  ('ddd', 10),
#  ('strin', 10),
#  ('ord', 10),
#  ('yushu', 10),
#  ('sprintf', 10),
#  ('abc', 10),
#  ('clear', 10),
#  ('linelen', 10),
#  ('gap', 10),
#  ('fei', 10),
#  ('bubblesort', 10),
#  ('high', 10),
#  ('iiiii', 10),
#  ('beichu', 10),
#  ('cwde', 10),
#  ('cache', 10),
#  ('vis', 10),
#  ('before', 9),
#  ('yinshu', 9),
#  ('dt', 9),
#  ('qwdm', 9),
#  ('yes', 9),
#  ('substr', 9),
#  ('right', 9),
#  ('months', 9),
#  ('multiply', 9),
#  ('form', 9),
#  ('bacteria', 9),
#  ('fuck', 9),
#  ('sj', 9),
#  ('isupper', 9),
#  ('prt', 9),
#  ('poi', 9),
#  ('bijiao', 9),
#  ('cx', 9),
#  ('ou', 9),
#  ('low', 9),
#  ('ab', 9),
#  ('tm', 9),
#  ('yaolen', 9),
#  ('fj', 9),
#  ('yu', 9),
#  ('common', 9),
#  ('seq', 9),
#  ('flight', 9),
#  ('back', 9),
#  ('step', 9),
#  ('moun', 9),
#  ('tjdm', 9),
#  ('va', 9),
#  ('matrixx', 9),
#  ('val', 9),
#  ('record', 9),
#  ('cheng', 8),
#  ('men', 8),
#  ('derta', 8),
#  ('group', 8),
#  ('rr', 8),
#  ('changdu', 8),
#  ('minn', 8),
#  ('d/', 8),
#  ('dd', 8),
#  ('down', 8),
#  ('fight', 8),
#  ('d\\nz', 8),
#  ('d\\ns', 8),
#  ('d\\nq', 8),
#  ('nixu', 8),
#  ('findmax', 8),
#  ('feof', 8),
#  ('djt', 8),
#  ('qx', 8),
#  ('tmpl', 8),
#  ('xiaoshi', 8),
#  ('copy', 8),
#  ('pri', 8),
#  ('ff', 8),
#  ('cmovle', 8),
#  ('two', 8),
#  ('duqu', 8),
#  ('remain', 8),
#  ('cen', 8),
#  ('qiwangs', 8),
#  ('kh', 8),
#  ('cell', 8),
#  ('circle', 8),
#  ('pe', 8),
#  ('zhuan', 8),
#  ('bn', 8),
#  ('odd', 8),
#  ('pipei', 8),
#  ('chu', 8),
#  ('auth', 8),
#  ('bec', 8),
#  ('ave', 8),
#  ('wei', 8),
#  ('replacement', 8),
#  ('display', 8),
#  ('wang', 7),
#  ('tianjis', 7),
#  ('andian', 7),
#  ('minus', 7),
#  ('ming', 7),
#  ('wusi', 7),
#  ('score', 7),
#  ('ill', 7),
#  ('height', 7),
#  ('suan', 7),
#  ('kid', 7),
#  ('fucomip', 7),
#  ('left', 7),
#  ('tshang', 7),
#  ('qiw', 7),
#  ('isspace', 7),
#  ('team', 7),
#  ('can', 7),
#  ('sr', 7),
#  ('sa', 7),
#  ('lencount', 7),
#  ('eq', 7),
#  ('place', 7),
#  ('xa', 7),
#  ('msize', 7),
#  ('fsize', 7),
#  ('average', 7),
#  ('checki', 7),
#  ('mark', 7),
#  ('putin', 7),
#  ('coutnoneg', 7),
#  ('sca', 7),
#  ('thorse', 7),
#  ('qhorse', 7),
#  ('known', 7),
#  ('fb', 7),
#  ('connect', 7),
#  ('countday', 7),
#  ('nian', 7),
#  ('sta', 7),
#  ('xibu', 7),
#  ('fangcha', 7),
#  ('set', 7),
#  ('used', 7),
#  ('yuan', 7),
#  ('ppow', 7),
#  ('per', 7),
#  ('lans', 7),
#  ('ctt', 7),
#  ('shanchu', 7),
#  ('chr', 7),
#  ('leapyear', 7),
#  ('trail', 7),
#  ('li', 7),
#  ('choose', 7),
#  ('putstr', 7),
#  ('qt', 7),
#  ('peidui', 7),
#  ('inda', 7),
#  ('fact', 7),
#  ('tianshu', 7),
#  ('fre', 7),
#  ('empty', 7),
#  ('zheng', 7),
#  ('type', 6),
#  ('ma', 6),
#  ('mk', 6),
#  ('rn', 6),
#  ('checkprime', 6),
#  ('fsubp', 6),
#  ('doit', 6),
#  ('tries', 6),
#  ('putapple', 6),
#  ('du', 6),
#  ('fscanf', 6),
#  ('yuanshi', 6),
#  ('medium', 6),
#  ('together', 6),
#  ('mizhi', 6),
#  ('fmax', 6),
#  ('checkbegin', 6),
#  ('substring', 6),
#  ('pure', 6),
#  ('sc', 6),
#  ('ex', 6),
#  ('ishuiwen', 6),
#  ('yue', 6),
#  ('zhuanhuan', 6),
#  ('jiange', 6),
#  ('oushu', 6),
#  ('numfemale', 6),
#  ('jw', 6),
#  ('assertions', 6),
#  ('pay', 6),
#  ('ok', 6),
#  ('ai', 6),
#  ('tr', 6),
#  ('woman', 6),
#  ('list', 6),
#  ('sang', 6),
#  ('shulie', 6),
#  ('method', 6),
#  ('numb', 6),
#  ('fff', 6),
#  ('feibo', 6),
#  ('leg', 6),
#  ('pg', 6),
#  ('look', 6),
#  ('leapy', 6),
#  ('fflush', 6),
#  ('shisushu', 6),
#  ('bo', 6),
#  ('fibo', 6),
#  ('.f', 6),
#  ('fldz', 6),
#  ('qian', 6),
#  ('zl', 6),
#  ('boolean', 6),
#  ('sgn', 6),
#  ('tar', 6),
#  ('faddp', 6),
#  ('tag', 6),
#  ('xqj', 6),
#  ('ln', 6),
#  ('daoxu', 6),
#  ('zuozhe', 6),
#  ('varieties', 6),
#  ('angle', 6),
#  ('key', 6),
#  ('qxia', 6),
#  ('ysf', 6),
#  ('ppatient', 6),
#  ('cntf', 6),
#  ('cifang', 6),
#  ('bianli', 6),
#  ('hb', 6),
#  ('limit', 6),
#  ('precision', 6),
#  ('pr', 6),
#  ('xijun', 5),
#  ('huiwenshu', 5),
#  ('children', 5),
#  ('replace', 5),
#  ('mi', 5),
#  ('wine', 5),
#  ('fac', 5),
#  ('d.', 5),
#  ('prin', 5),
#  ('coutt', 5),
#  ('dg', 5),
#  ('next', 5),
#  ('blen', 5),
#  ('seven', 5),
#  ('ppp', 5),
#  ('baifang', 5),
#  ('imim', 5),
#  ('nf', 5),
#  ('inverse', 5),
#  ('flu', 5),
#  ('sb', 5),
#  ('increase', 5),
#  ('daodan', 5),
#  ('ano', 5),
#  ('germs', 5),
#  ('leapyearmonth', 5),
#  ('ju', 5),
#  ('former', 5),
#  ('author', 5),
#  ('istore', 5),
#  ('yeariiiii', 5),
#  ('speed', 5),
#  ('leta', 5),
#  ('letb', 5),
#  ('sums', 5),
#  ('jud', 5),
#  ('fuhao', 5),
#  ('tp', 5),
#  ('decide', 5),
#  ('qmg', 5),
#  ('full', 5),
#  ('hour', 5),
#  ('maxright', 5),
#  ('yy', 5),
#  ('findday', 5),
#  ('operation', 5),
#  ('banji', 5),
#  ('buf', 5),
#  ('remove', 5),
#  ('swi', 5),
#  ('origin', 5),
#  ('findlen', 5),
#  ('outputdata', 5),
#  ('monthday', 5),
#  ('rui', 5),
#  ('ba', 5),
#  ('maxlen', 5),
#  ('breed', 5),
#  ('bracket', 5),
#  ('lena', 5),
#  ('gg', 5),
#  ('nummale', 5),
#  ('bknown', 5),
#  ('judgeyear', 5),
#  ('need', 5),
#  ('sig', 5),
#  ('dao', 5),
#  ('dat', 5),
#  ('route', 5),
#  ('final', 5),
#  ('lastnumber', 5),
#  ('rearrange', 5),
#  ('gram', 5),
#  ('qh', 5),
#  ('equal', 5),
#  ('value', 5),
#  ('vb', 5),
#  ('cntm', 5),
#  ('sequence', 5),
#  ('minleft', 5),
#  ('pool', 5),
#  ('hh', 5),
#  ('commonyearmonth', 5),
#  ('stat', 5),
#  ('', 4),
#  ('direct', 4),
#  ('credit', 4),
#  ('countt', 4),
#  ('xueshen', 4),
#  ('tell', 4),
#  ('haha', 4),
#  ('femalecnt', 4),
#  ('mj', 4),
#  ('my', 4),
#  ('fibonacci', 4),
#  ('end', 4),
#  ('xj', 4),
#  ('zhongliu', 4),
#  ('alen', 4),
#  ('tianjie', 4),
#  ('zuida', 4),
#  ('houzi', 4),
#  ('nta', 4),
#  ('huanhang', 4),
#  ('toy', 4),
#  ('lanjie', 4),
#  ('getarray', 4),
#  ('jcount', 4),
#  ('jueduizhi', 4),
#  ('points', 4),
#  ('jiafa', 4),
#  ('de', 4),
#  ('filename', 4),
#  ('outcome', 4),
#  ('pre', 4),
#  ('fema', 4),
#  ('pro', 4),
#  ('ip', 4),
#  ('malecnt', 4),
#  ('hand', 4),
#  ('chengji', 4),
#  ('freopen', 4),
#  ('plu', 4),
#  ('noshowpos', 4),
#  ('lenofr', 4),
#  ('maximum', 4),
#  ('nn', 4),
#  ('hebin', 4),
#  ('primei', 4),
#  ('maopao', 4),
#  ('string', 4),
#  ('die', 4),
#  ('dir', 4),
#  ('mergesort', 4),
#  ('mincol', 4),
#  ('memory', 4),
#  ('showpos', 4),
#  ('erchashu', 4),
#  ('write', 4),
#  ('grow', 4),
#  ('sw', 4),
#  ('jie', 4),
#  ('jia', 4),
#  ('ee', 4),
#  ('routey', 4),
#  ('routex', 4),
#  ('xi', 4),
#  ('one', 4),
#  ('weekdays', 4),
#  ('firstout', 4),
#  ('outd', 4),
#  ('arrayv', 4),
#  ('take', 4),
#  ('destroy', 4),
#  ('normal', 4),
#  ('buffer', 4),
#  ('ccount', 4),
#  ('invert', 4),
#  ('geshu', 4),
#  ('modes', 4),
#  ('detc', 4),
#  ('lon', 4),
#  ('ffabs', 4),
#  ('bucket', 4),
#  ('cbw', 4),
#  ('legal', 4),
#  ('fab', 4),
#  ('small', 4),
#  ('tel', 4),
#  ('pailie', 4),
#  ('palin', 4),
#  ('amount', 4),
#  ('select', 4),
#  ('vi', 4),
#  ('dec', 4),
#  ('fr', 4),
#  ('fa', 4),
#  ('numa', 4),
#  ('fi', 4),
#  ('fk', 4),
#  ('grade', 4),
#  ('shuzi', 4),
#  ('reduce', 4),
#  ('nowlen', 4),
#  ('longtime', 4),
#  ('guess', 4),
#  ('ispr', 4),
#  ('highestpos', 4),
#  ('quicksort', 4),
#  ('setp', 4),
#  ('play', 4),
#  ('charu', 4),
#  ('exp', 4),
#  ('femail', 4),
#  ('printarray', 4),
#  ('totalmember', 4),
#  ('po', 4),
#  ('kuohao', 4),
#  ('jianli', 4),
#  ('oho', 4),
#  ('cul', 4),
#  ...]

# %%
dictionary = dict()
for word,_ in count:
    print word
    dictionary[word] = len(dictionary)
len(dictionary)
# Out:
# UNK
# $
# ,
# mov
# +
# [
# ]
# rbp
# eax
# var
# rax
# :
# add
# loc
# rdx
# edx
# short
# cmp
# call
# <
# std
# char
# *
# lea
# cdqe
# >
# sub
# jmp
# offset
# edi
# rcx
# ecx
# shl
# movsxd
# rsi
# )
# (
# esi
# ostream
# rdi
# s
# al
# rsp
# &
# jz
# traits
# operator
# movzx
# jnz
# xor
# fs
# movsd
# jge
# int
# imul
# push
# jg
# jle
# ptr
# sar
# printf
# test
# scanf
# basic
# ds
# retn
# format
# chk
# stack
# fail
# leave
# locret
# rbx
# cs
# istream
# byte
# d
# c
# movss
# pxor
# qword
# dword
# movsx
# const
# pop
# jl
# endl
# strlen
# nop
# dl
# putchar
# puts
# mulsd
# movapd
# shr
# unk
# ucomisd
# ebx
# subsd
# divsd
# addsd
# rep
# stosq
# a
# jbe
# x
# gets
# edata
# n
# js
# src
# and
# idiv
# cdq
# base
# getchar
# sqrt
# dest
# double
# void
# setz
# setnz
# i
# memset
# ios
# setnle
# long
# jb
# size
# ucomiss
# neg
# jnb
# div
# getline
# cl
# malloc
# strcmp
# strcpy
# f
# jp
# ja
# mulss
# subss
# addss
# b
# lf
# get
# d\n
# movq
# xorpd
# mul
# asc
# j
# y
# divss
# movaps
# pow
# m
# float
# k
# jns
# off
# setprecision
# fixed
# num
# cos
# ax
# cqo
# nmemb
# nptr
# c=
# p
# sum
# main
# andpd
# free
# s\n
# t
# qsort
# compar
# cmovs
# str
# reverse
# sort
# l
# xorps
# setl
# setnb
# max
# sushu
# d=
# haystack
# or
# stu
# temp
# -
# q
# =
# setnbe
# strcat
# g
# len
# judge
# word
# ii
# needle
# change
# ld
# prime
# c\n
# iii
# sil
# ans
# print
# andps
# atoi
# setle
# check
# r
# lf\n
# min
# huiwen
# paixu
# setnl
# swap
# e
# count
# st
# input
# total
# array
# calloc
# strncpy
# h
# dil
# flag
# w
# data
# z
# days
# su
# row
# student
# node
# year
# leap
# day
# result
# apple
# dis
# panduan
# strstr
# col
# floor
# fun
# output
# uint
# creat
# dx
# move
# sz
# number
# board
# line
# length
# find
# out
# read
# match
# cal
# not
# tmp
# movd
# in
# queue
# dp
# isprime
# ss
# boy
# o
# cmovnz
# shuchu
# month
# tian
# order
# run
# search
# setnp
# stream
# combine
# cnt
# bubble
# atof
# work
# first
# shuru
# head
# map
# pd
# function
# hui
# u
# person
# toupper
# repne
# date
# scasb
# put
# trans
# area
# room
# movsq
# fenjie
# mat
# compare
# point
# hebing
# money
# res
# isalpha
# nm
# tj
# ld=
# tianji
# jiaogu
# com
# girl
# runnian
# matrix
# qiwang
# an
# v
# dijitian
# la
# exchange
# qw
# power
# female
# mon
# zhishu
# func
# turn
# exit
# status
# times
# divide
# fld
# scan
# is
# male
# log
# fmod
# strchr
# fstp
# pai
# del
# insert
# memcpy
# rank
# ulong
# f\n
# sen
# delim
# aa
# create
# arrange
# strtok
# calc
# tot
# child
# mx
# s=
# solve
# win
# lb
# qq
# qi
# distance
# sign
# to
# convert
# state
# ioinit
# shuzu
# factor
# he
# re
# im
# up
# ji
# tem
# king
# chang
# stud
# px
# hang
# of
# arr
# arg
# bb
# calculate
# name
# pat
# aaa
# grids
# hw
# ceil
# deal
# people
# way
# pos
# jishu
# ys
# lie
# ignore
# patient
# zhi
# zh
# from
# ren
# zfc
# ch
# know
# second
# tree
# mianji
# mo
# zimu
# qj
# exam
# pan
# abs
# jilu
# shu
# shang
# dy
# peek
# xx
# init
# link
# use
# fen
# counter
# merge
# rev
# rec
# stum
# ld\n
# juli
# isrunnian
# words
# book
# isleapyear
# na
# man
# comp
# txia
# start
# all
# fy
# jiaohuan
# dui
# pp
# zhao
# qshang
# spread
# schsum
# jh
# juzhen
# issushu
# dfs
# sex
# fang
# pa
# cut
# big
# jisuan
# bl
# monkey
# tolower
# ci
# answer
# lenth
# reserve
# sentence
# zuo
# fanxu
# now
# begin
# fan
# guiling
# go
# hanshu
# course
# fbnq
# fib
# make
# shift
# ways
# week
# th
# lc
# tran
# fild
# iiii
# third
# best
# xiaojian
# islower
# digui
# same
# bac
# jian
# tt
# zero
# kk
# single
# cha
# '
# cc
# paidui
# sscanf
# indata
# even
# hou
# after
# freq
# isalnum
# letter
# putout
# queen
# strncmp
# tong
# old
# devide
# strncat
# jd
# fgets
# op
# ansn
# dist
# sch
# qiwange
# xiao
# process
# ct
# tbyte
# huan
# inv
# weilen
# cmovge
# aut
# operate
# dst
# maxn
# level
# fanzhi
# sq
# yeari
# square
# xb
# show
# ddd
# strin
# ord
# yushu
# sprintf
# abc
# clear
# linelen
# gap
# fei
# bubblesort
# high
# iiiii
# beichu
# cwde
# cache
# vis
# before
# yinshu
# dt
# qwdm
# yes
# substr
# right
# months
# multiply
# form
# bacteria
# fuck
# sj
# isupper
# prt
# poi
# bijiao
# cx
# ou
# low
# ab
# tm
# yaolen
# fj
# yu
# common
# seq
# flight
# back
# step
# moun
# tjdm
# va
# matrixx
# val
# record
# cheng
# men
# derta
# group
# rr
# changdu
# minn
# d/
# dd
# down
# fight
# d\nz
# d\ns
# d\nq
# nixu
# findmax
# feof
# djt
# qx
# tmpl
# xiaoshi
# copy
# pri
# ff
# cmovle
# two
# duqu
# remain
# cen
# qiwangs
# kh
# cell
# circle
# pe
# zhuan
# bn
# odd
# pipei
# chu
# auth
# bec
# ave
# wei
# replacement
# display
# wang
# tianjis
# andian
# minus
# ming
# wusi
# score
# ill
# height
# suan
# kid
# fucomip
# left
# tshang
# qiw
# isspace
# team
# can
# sr
# sa
# lencount
# eq
# place
# xa
# msize
# fsize
# average
# checki
# mark
# putin
# coutnoneg
# sca
# thorse
# qhorse
# known
# fb
# connect
# countday
# nian
# sta
# xibu
# fangcha
# set
# used
# yuan
# ppow
# per
# lans
# ctt
# shanchu
# chr
# leapyear
# trail
# li
# choose
# putstr
# qt
# peidui
# inda
# fact
# tianshu
# fre
# empty
# zheng
# type
# ma
# mk
# rn
# checkprime
# fsubp
# doit
# tries
# putapple
# du
# fscanf
# yuanshi
# medium
# together
# mizhi
# fmax
# checkbegin
# substring
# pure
# sc
# ex
# ishuiwen
# yue
# zhuanhuan
# jiange
# oushu
# numfemale
# jw
# assertions
# pay
# ok
# ai
# tr
# woman
# list
# sang
# shulie
# method
# numb
# fff
# feibo
# leg
# pg
# look
# leapy
# fflush
# shisushu
# bo
# fibo
# .f
# fldz
# qian
# zl
# boolean
# sgn
# tar
# faddp
# tag
# xqj
# ln
# daoxu
# zuozhe
# varieties
# angle
# key
# qxia
# ysf
# ppatient
# cntf
# cifang
# bianli
# hb
# limit
# precision
# pr
# xijun
# huiwenshu
# children
# replace
# mi
# wine
# fac
# d.
# prin
# coutt
# dg
# next
# blen
# seven
# ppp
# baifang
# imim
# nf
# inverse
# flu
# sb
# increase
# daodan
# ano
# germs
# leapyearmonth
# ju
# former
# author
# istore
# yeariiiii
# speed
# leta
# letb
# sums
# jud
# fuhao
# tp
# decide
# qmg
# full
# hour
# maxright
# yy
# findday
# operation
# banji
# buf
# remove
# swi
# origin
# findlen
# outputdata
# monthday
# rui
# ba
# maxlen
# breed
# bracket
# lena
# gg
# nummale
# bknown
# judgeyear
# need
# sig
# dao
# dat
# route
# final
# lastnumber
# rearrange
# gram
# qh
# equal
# value
# vb
# cntm
# sequence
# minleft
# pool
# hh
# commonyearmonth
# stat
#
# direct
# credit
# countt
# xueshen
# tell
# haha
# femalecnt
# mj
# my
# fibonacci
# end
# xj
# zhongliu
# alen
# tianjie
# zuida
# houzi
# nta
# huanhang
# toy
# lanjie
# getarray
# jcount
# jueduizhi
# points
# jiafa
# de
# filename
# outcome
# pre
# fema
# pro
# ip
# malecnt
# hand
# chengji
# freopen
# plu
# noshowpos
# lenofr
# maximum
# nn
# hebin
# primei
# maopao
# string
# die
# dir
# mergesort
# mincol
# memory
# showpos
# erchashu
# write
# grow
# sw
# jie
# jia
# ee
# routey
# routex
# xi
# one
# weekdays
# firstout
# outd
# arrayv
# take
# destroy
# normal
# buffer
# ccount
# invert
# geshu
# modes
# detc
# lon
# ffabs
# bucket
# cbw
# legal
# fab
# small
# tel
# pailie
# palin
# amount
# select
# vi
# dec
# fr
# fa
# numa
# fi
# fk
# grade
# shuzi
# reduce
# nowlen
# longtime
# guess
# ispr
# highestpos
# quicksort
# setp
# play
# charu
# exp
# femail
# printarray
# totalmember
# po
# kuohao
# jianli
# oho
# cul
# couple
# absd
# bingren
# feb
# subtract
# range
# info
# cii
# cin
# houwang
# fclose
# gb
# gl
# outda
# zz
# append
# ctr
# chi
# bigint
# sushui
# xianshi
# findmin
# hight
# le
# dispose
# lu
# inputdata
# cishu
# numout
# feibonaqi
# mid
# mix
# maxrow
# cw
# yao
# yan
# daysum
# multi
# align
# readin
# checkend
# setb
# setw
# countyear
# wer
# locate
# column
# letters
# chuli
# rizi
# hm
# ind
# inc
# stringv
# eof
# dert
# zhsh
# four
# pingrun
# counts
# hospital
# juedui
# exch
# chartonum
# enter
# gujiao
# fim
# unvis
# ru
# xu
# dayr
# shushu
# mini
# maxi
# judgeline
# dom
# d-
# di
# yuesefu
# ishw
# cai
# nsen
# newhead
# factorize
# three
# ifsushu
# puti
# isodd
# panrun
# outtime
# isgraph
# findpair
# qianshou
# maxii
# born
# foo
# subs
# sol
# knowwho
# joseph
# time
# rechange
# itruth
# maxnum
# ls
# ranking
# fpg
# ping
# produce
# sx
# sl
# mail
# killer
# space
# nums
# ori
# oper
# xs
# kuso
# multiple
# dayii
# strupr
# getin
# repl
# fanxushu
# fe
# checka
# whoknow
# cancer
# anti
# susu
# intime
# nx
# getmemory
# cg
# summ
# nu
# tongji
# strrev
# jiao
# printnum
# jue
# au
# ansm
# hws
# follow
# far
# mult
# zzhzb
# ercha
# osubstr
# depart
# yesorno
# fx
# fz
# pand
# fjys
# inve
# elder
# done
# sm
# gpa
# aver
# wlen
# beichushu
# last
# load
# tgt
# pb
# pi
# pm
# infect
# fuc
# reads
# pdss
# saima
# distances
# cout
# coun
# bin
# game
# pep
# be
# bw
# into
# sqrtf
# u=
# fzh
# checkhui
# once
# rankgame
# entire
# usd
# sample
# getnum
# fsort
# bing
# lw
# lp
# factorization
# fdivrp
# juzi
# echo
# zhengshu
# hz
# duma
# hefa
# judgeletter
# means
# fenfa
# zhuanhua
# ushort
# cn
# cf
# cr
# aw
# surface
# xiaoling
# diandao
# isub
# abss
# weishu
# cnum
# checksu
# daycount
# hs
# hf
# dayfr
# duru
# mysort
# factors
# sqr
# loe
# minhang
# aur
# alphabetic
# digit
# fanzhuan
# yeariii
# ref
# chuanran
# chen
# undi
# join
# qiufan
# tw
# lwr
# mf
# mm
# example
# gede
# eng
# dayofm
# fscan
# jianyan
# over
# fig
# combination
# proce
# birth
# scholar
# rp
# ifprime
# fangda
# shusu
# delsp
# handinhand
# huanwei
# memcmp
# accountdays
# subduction
# nametimes
# minv
# maxx
# maxh
# bianxu
# mouth
# palindrome
# dosomething
# fooiiii
# do
# primjud
# solutionnum
# stop
# searchjoint
# bwin
# strnu
# ryear
# xiaochu
# monthii
# toprint
# tushu
# con
# path
# atgc
# daynum
# fflag
# myrank
# delmin
# slv
# conv
# if
# zhiyinshu
# puttogether
# thi
# the
# zerocol
# integer
# han
# zhisu
# opt
# opp
# ope
# valueii
# qiumax
# zch
# txt
# for
# iszhishu
# post
# chuan
# transform
# monthlength
# converse
# rowmax
# isit
# yuandan
# isin
# delete
# mdays
# shit
# getstr
# ny
# battle
# pei
# division
# birev
# minute
# diy
# quick
# upper
# mhang
# yiwei
# strlw
# boo
# ipt
# prove
# dudu
# reorder
# countnum
# fuction
# cao
# spp
# refine
# isequal
# clearerr
# divider
# product
# calday
# diaohuan
# so
# sd
# years
# tashisushu
# mystrlen
# mlie
# fopen
# zuobian
# youxiu
# antitone
# qm
# xl
# xg
# fh
# yin
# germ
# than
# apples
# minword
# decompose
# wayx
# strf
# germf
# shifouzimu
# tozero
# leapyearjudgement
# fda
# gen
# checkp
# ir
# susucheck
# bianyuan
# relative
# minlie
# wayy
# checkr
# isrunyear
# fnt
# xunzhao
# kjj
# toup
# comb
# yidong
# cuo
# isok
# developing
# ifhuiwen
# diverse
# bian
# jianfa
# no
# gdt
# getword
# msees
# remember
# yearii
# findout
# memmove
# deduct
# fgetc
# exin
# runyue
# ngram
# sheng
# wordsnumber
# areo
# ap
# getcmp
# av
# oppoorder
# fanwei
# god
# huige
# zuob
# fchs
# ty
# ts
# nametemp
# getday
# dists
# ten
# peiyang
# dian
# sun
# countsum
# modify
# yuefen
# pick
# sxpl
# burun
# horses
# stick
# daysi
# judgeprime
# atn
# vs
# numberi
# dingwei
# phead
# newnum
# biaozhi
# fw
# fenpei
# numi
# fuzhi
# maxhui
# yuqiwuguan
# yn
# istarget
# toscan
# ast
# awin
# catenate
# top
# daysfromfirst
# differ
# meishu
# part
# tonum
# reproduce
# kind
# totalfromfirstday
# xiangsu
# miao
# mian
# build
# most
# jss
# alpha
# exc
# yearbegin
# changeplace
# inputarray
# see
# sec
# arn
# please
# yici
# yuanlen
# uup
# guocheng
# notallfilled
# asdf
# pk
# cincd
# transfor
# calender
# identf
# yinzi
# chess
# setbe
# seperate
# feirun
# turntonum
# nextday
# setfill
# panduansushu
# d\t
# iiiiii
# within
# countr
# rowi
# maxword
# atol
# delta
# numcount
# nax
# clean
# getarea
# stubid
# ge
# factoring
# pymbg
# za
# zb
# fold
# zy
# cat
# primenumber
# evennumber
# body
# arrive
# getdist
# weekday
# largen
# app
# zimuxiahuaxian
# getup
# infection
# account
# meet
# guochen
# whichmonth
# issu
# zhengchang
# findbat
# comma
# fblq
# relativeto
# subtraction
# hands
# books
# pingguo
# rem
# math
# que
# agetemp
# xifff
# lth
# shangyigejiedian
# revchk
# maze
# zhii
# strre
# daycounting
# guowang
# fxs
# qingling
# propagate
# tall
# xieru
# szs
# fxch
# boynum
# cube
# strpos
# kong
# qr
# qz
# coli
# lj
# ca
# ysj
# jidian
# xiangguan
# effect
# judgment
# lashou
# zyk
# missle
# pdjsc
# boom
# fmulp
# five
# dish
# islegal
# lose
# platforms
# avoid
# kuosan
# ccout
# lujing
# shengxu
# canliang
# sqare
# baoshu
# hi
# hd
# compute
# veget
# fldcw
# dayprint
# sick
# zerorow
# chance
# friends
# iszs
# fout
# recycle
# fistp
# isoushu
# every
# inum
# solution
# putcc
# calarea
# xingqi
# chek
# panbie
# nem
# checknum
# conduct
# mem
# functio
# stevie
# cdet
# reada
# printv
# printa
# printc
# charnum
# dna
# funcofa
# hanoi
# tail
# program
# liezuixiao
# ishui
# notii
# gradetogpa
# inttostr
# award
# inttochar
# bysum
# moin
# shoot
# md
# gpai
# ml
# setup
# mn
# scanfing
# fking
# meide
# numcheck
# iflet
# forodd
# mppx
# verify
# classify
# lao
# disassemble
# laf
# wrong
# zhengli
# types
# stri
# upside
# strc
# sortarr
# oni
# fit
# fix
# production
# crea
# qpstr
# findking
# averse
# side
# shirunnian
# skipstring
# insertb
# xgy
# zhaodui
# zhaosushu
# rt
# gaocheng
# breakways
# factorii
# tiao
# sym
# topjudge
# subtr
# dayv
# filter
# isi
# xun
# miaoshu
# shuzhi
# hook
# toj
# tol
# qsortb
# inputnumbers
# scanarray
# daysnotleap
# minl
# minm
# ran
# mread
# minf
# maxapple
# longl
# mins
# seek
# minu
# chulie
# pdhw
# maxj
# bigprint
# amnt
# disassamble
# newline
# pnt
# inttochr
# datai
# dol
# combarr
# highget
# wordlen
# bomb
# josephus
# loaddata
# sui
# kuo
# layout
# couts
# biubiu
# thirteen
# dn
# ston
# dr
# bat
# perror
# bad
# emp
# runi
# strnl
# bai
# selectsort
# clen
# exponent
# shubingpai
# sortb
# isjishu
# feibonaqishulie
# sorts
# ferbo
# wc
# wa
# wu
# ws
# g\n
# buzhou
# huanh
# opration
# cmovl
# contribution
# reorderb
# inf
# guil
# lunhuan
# fri
# tiny
# anyil
# turntoten
# highcal
# ydays
# zuhe
# xxx
# worker
# dota
# ascmax
# mokey
# applesi
# rema
# procedure
# canf
# cons
# cont
# dajianfa
# divmet
# it
# setin
# caozuo
# ohyeah
# io
# ia
# ic
# ib
# mouse
# id
# findknot
# split
# cir
# qiuyu
# updown
# permutation
# xinqi
# mutiply
# qsorta
# gongxian
# getsum
# bigmulti
# just
# photo
# distribute
# rns
# repick
# oddnum
# countl
# handshake
# shumu
# shoui
# initialise
# has
# opr
# survival
# brr
# getaverage
# getf
# opl
# fangjungen
# maxim
# rever
# hypot
# statistic
# rangestr
# doublesort
# bottom
# rezero
# paib
# allocate
# fob
# paic
# hsb
# core
# hsa
# posi
# ascanf
# deletev
# lianjie
# plusbig
# movenum
# deletes
# plug
# plus
# zui
# subv
# son
# ppt
# gir
# imin
# checkrun
# ganster
# analyse
# strqp
# moveforward
# dump
# combinestr
# leapyeari
# yueshu
# cunzai
# rnfeb
# exist
# allfilled
# ni
# leftpos
# shrink
# ntos
# squ
# substract
# discharge
# pseudo
# backward
# danci
# chain
# .lf\n
# turntob
# zong
# juzheng
# charge
# hangxiao
# nihao
# arraycout
# cool
# jisuanb
# addauthor
# printfing
# bg
# mgpa
# baka
# adds
# appear
# chufa
# orde
# lefts
# minnum
# addd
# addc
# houc
# basec
# bj
# newnode
# whatmark
# hubing
# convertor
# turnback
# judgechar
# atoten
# yearday
# fbn
# monthv
# prop
# swep
# judgenum
# separy
# getadd
# rtrt
# maxasc
# fly
# judm
# cas
# car
# cap
# fooii
# judy
# fenjieyinshi
# spe
# huiwenjud
# kingmonkey
# divi
# divd
# mao
# sy
# joint
# sh
# mostbook
# sf
# yearv
# quanganran
# numchange
# istrue
# nima
# colmin
# judgebegin
# monkeyking
# getlinked
# commoninteger
# inits
# half
# nor
# gbc
# term
# jiaodian
# printarr
# revers
# isnum
# maxlocate
# dawang
# ec
# er
# fsubrp
# strbigint
# godbah
# checkstr
# minapple
# factorsii
# rlt
# numf
# dayofy
# ture
# shuliang
# yearsiii
# zai
# reslove
# carry
# gotozero
# yid
# msort
# jieguo
# fraction
# memo
# houzhui
# twopoint
# rlti
# rowset
# ana
# ann
# chengfa
# mymin
# noti
# findoutmax
# trace
# xiaojie
# dicide
# qishu
# putapp
# pair
# solutionnumber
# infectionv
# isrn
# oddoreven
# shot
# shou
# jizu
# mainv
# hack
# totalday
# enough
# ciicc
# fenj
# fangcheng
# fornot
# ctruth
# primejud
# sss
# sortdata
# ssd
# appendnewnode
# ismax
# sear
# vampire
# detect
# cacul
# checkd
# checke
# checkb
# checkc
# behind
# waye
# jx
# fibbnacci
# dosum
# jf
# come
# requeue
# many
# dmin
# por
# cancel
# mystrcmp
# save
# yzs
# conflate
# yixu
# ^
# sorthuiwen
# programme
# pymed
# fengjie
# chrtoint
# biao
# binary
# pal
# isturn
# firstday
# yd
# changing
# yf
# dnapair
# srev
# without
# bottle
# scholarship
# jzhh
# kill
# appleii
# resm
# noghus
# fangpingguo
# selectionsort
# xiaohang
# suml
# ifs
# chengfang
# putdata
# draw
# xiaolie
# qianc
# kmp
# oh
# stand
# os
# youk
# bjj
# seekmax
# series
# fenpingguo
# tiffany
# findri
# jun
# cycle
# with
# yunsuan
# setapples
# define
# ad
# ah
# am
# rvs
# ar
# xishu
# az
# movev
# again
# you
# wuguan
# yos
# trisort
# separate
# ansv
# much
# biprt
# qsorting
# bacnum
# cpy
# guilinhang
# hxprint
# resolution
# cpu
# scn
# zuok
# lian
# tz
# lineset
# tf
# tc
# toten
# got
# jichuan
# huiwenzichuan
# delsuffix
# wsj
# leftnum
# adjust
# cvt
# minaaaa
# heping
# past
# brackets
# suo
# gether
# sus
# sup
# lld
# hash
# ggg
# trunc
# ahead
# mpow
# zichuan
# calcu
# vir
# huiw
# maxaaaa
# stable
# problem
# downsort
# xunhuan
# share
# ps
# numberv
# waynum
# hhh
# hei
# getarr
# guilinlie
# fp
# fv
# fc
# fg
# mingliu
# jiang
# josafe
# departure
# judgep
# julishi
# ciii
# member
# wrh
# cutin
# pend
# alter
# strlwr
# yi
# dijigeshu
# yk
# zhen
# yz
# detach
# bigger
# decimal
# found
# inrange
# junfangcha
# fenpg
# asd
# arrsort
# pairs
# multiplus
# round
# abciii
# oppo
# feed
# flood
# primechart
# numbet
# lookfor
# zd
# toi
# passed
# store
# jiangxuejin
# sortprime
# john
# noblank
# kakutani
# tentob
# arrang
# sssss
# bukong
# dividemin
# liu
# grems
# index
# chart
# chari
# ifrun
# kg
# cover
# zpjd
# qium
# western
# chanel
# fnstcw
# merger
# less
# bfs
# columns
# liexiao
# lunhun
# longest
# combinationv
# enemy
# resolve
# cry
# investigate
# cre
# itype
# sep
# printout
# daysbetweendate
# arc
# are
# sel
# zkh
# fucomi
# ranker
# complement
# findn
# monckycircle
# findm
# fxiao
# connection
# findx
# findr
# sweet
# manners
# xijunfanzhi
# suanweishu
# pt
# paiban
# pc
# pf
# dstbt
# pl
# ifhw
# funa
# gai
# funb
# imat
# toge
# priii
# kuai
# tiaosheng
# problemiii
# loop
# readb
# guolv
# xian
# rid
# minih
# minii
# minil
# belong
# shorten
# checking
# shai
# shan
# rearange
# mcomb
# leapi
# ccin
# plate
# ntianshu
# self
# ijudge
# inpue
# location
# finder
# ouchuan
# disorder
# sgl
# methods
# numc
# jiaziji
# eliminate
# renshu
# proc
# bd
# bf
# bi
# maxbook
# virus
# breakup
# idb
# block
# ida
# rows
# isround
# bubblesortb
# isidentifor
# submin
# sdu
# myfunc
# sdw
# boyi
# atob
# don
# reek
# father
# zha
# getint
# getone
# zhh
# backprint
# getmarried
# disintegerate
# youxi
# jch
# ifunlucky
# tempbec
# jhsz
# dot
# plalindrome
# xbj
# minusn
# ysfwt
# linemin
# getking
# gc
# gj
# compose
# sushul
# monthiiii
# young
# strsub
# decomposition
# duilie
# allocable
# zengjia
# ifsu
# outresult
# funcofb
# funcofc
# funcofd
# jieshang
# eva
# marry
# race
# nseven
# zn
# zi
# sortnum
# zx
# recur
# bdx
# proliferation
# zhenghe
# bdet
# jiangjin
# namef
# manage
# zuocha
# names
# chf
# tochar
# fibs
# cho
# chq
# chs
# fer
# bujili
# evennum
# tianshucha
# on
# initial
# judgeh
# bisum
# slove
# feii
# tab
# hign
# gcd
# sim
# jvzhen
# ox
# getnumb
# getnuma
# da
# delend
# element
# qushu
# checkyear
# maopaopaixu
# panduanfanwen
# least
# kbr
# lh
# dq
# qipa
# sword
# factorial
# makeanti
# handi
# noempty
# kiss
# mode
# doing
# moveahead
# mas
# nextmax
# measure
# applenum
# tento
# matf
# rennian
# shuu
# monkeynum
# qut
# insii
# nimei
# shun
# isright
# shortest
# indent
# moveiiii
# mdisp
# qualification
# suffix
# hehe
# outputiiii
# dayofyear
# getlength
# shortl
# daopai
# enought
# showpoint
# reproduction
# reordera
# issn
# caculate
# readdata
# typefu
# saintseiya
# ganran
# linknode
# biii
# cauclute
# gaoxiao
# anaylse
# huiwenl
# mjs
# ghl
# d\n\n
# why
# pingjun
# gather
# request
# brea
# sorta
# stract
# daysleap
# diji
# shi
# zhongshu
# pause
# getdata
# beijianshu
# paixub
# paixua
# aiii
# act
# qp
# qu
# lala
# whether
# isgoodsubstr
# contain
# hangzuida
# fdis
# seperatesort
# error
# kaifang
# reform
# gpoint
# progress
# luo
# everydouble
# kej
# lg
# joy
# addit
# tx
# ck
# cj
# co
# kingf
# ce
# cz
# ismatrix
# cp
# bianhao
# addition
# cutsign
# zhonglei
# wtf
# lgm
# findl
# cor
# resort
# jiangj
# hewroteit
# jay
# demo
# getdif
# vv
# typezh
# ava
# zhaoyinshu
# cjj
# shijinzhi
# cross
# countdate
# games
# fabo
# cins
# zhaoren
# ghus
# kingii
# maintoo
# powe
# rintf
# distant
# muti
# gmm
# zifu
# getmap
# strplus
# manzu
# qiansan
# strrpl
# kkkk
# testc
# lenstr
# strchange
# zhaodao
# absf
# adet
# bubblesorta
# proliferate
# library
# a-z
# star
# miner
# does
# bwprint
# decline
# printsqr
# doublemonth
# chouqu
# paste
# due
# luna
# transfer
# jzb
# conbine
# damn
# febonaqi
# hv
# hu
# jianshu
# ha
# xuefen
# distribution
# miniiii
# mtod
# decprime
# chenger
# ins
# ini
# bool
# buqi
# kinds
# zhou
# judgerr
# deter
# qufen
# dayiiiiii
# spinout
# putapples
# 2652

# %%
dictionary
# Out:
# {'': 883,
#  'gai': 2309,
#  'weilen': 549,
#  'dert': 1055,
#  'zhsh': 1056,
#  'four': 1057,
#  'fout': 1627,
#  'minhang': 1233,
#  'const': 83,
#  'calculate': 400,
#  'shuru': 295,
#  'aur': 1234,
#  'swap': 224,
#  'alphabetic': 1235,
#  'femalecnt': 890,
#  'digit': 1236,
#  'fistp': 1629,
#  'void': 119,
#  'isoushu': 1630,
#  'every': 1631,
#  'fanzhuan': 1237,
#  'scholar': 1260,
#  'pingrun': 1058,
#  'ref': 1239,
#  'solution': 1633,
#  'putcc': 1634,
#  'chuanran': 1240,
#  'cmp': 17,
#  'xijun': 799,
#  'direct': 884,
#  'complement': 2289,
#  'calarea': 1635,
#  'second': 423,
#  'brr': 1848,
#  'huiwenshu': 800,
#  'chen': 1241,
#  'xingqi': 1636,
#  'chek': 1637,
#  'even': 523,
#  'panbie': 1638,
#  'nem': 1639,
#  'neg': 130,
#  '+': 4,
#  'tianji': 323,
#  'children': 801,
#  'checknum': 1640,
#  'setprecision': 162,
#  'cheng': 615,
#  'conduct': 1641,
#  'isleapyear': 452,
#  'mem': 1642,
#  'join': 1243,
#  'men': 616,
#  'path': 1293,
#  'functio': 1643,
#  'stevie': 1644,
#  'k': 159,
#  'credit': 885,
#  'cdet': 1645,
#  'lineset': 2155,
#  'divide': 345,
#  'printv': 1647,
#  'cmovge': 550,
#  'replace': 802,
#  'printa': 1648,
#  'substr': 584,
#  'printc': 1649,
#  'printf': 60,
#  'counts': 1059,
#  'total': 229,
#  'countt': 886,
#  'getchar': 115,
#  'shuchu': 281,
#  'charnum': 1650,
#  'dna': 1651,
#  'funcofa': 1652,
#  'lwr': 1246,
#  'hospital': 1060,
#  'hanoi': 1653,
#  'tail': 1654,
#  'dajianfa': 1810,
#  'program': 1655,
#  'call': 18,
#  'liezuixiao': 1656,
#  'xueshen': 887,
#  'calc': 367,
#  'type': 724,
#  'tell': 888,
#  'aut': 551,
#  'ishui': 1657,
#  'notii': 1658,
#  'gradetogpa': 1659,
#  'jmp': 27,
#  'haha': 889,
#  'inttostr': 1660,
#  'award': 1661,
#  'inttochar': 1662,
#  'recycle': 1628,
#  'bysum': 1663,
#  'moin': 1664,
#  'exch': 1062,
#  'shoot': 1665,
#  'md': 1666,
#  'mf': 1247,
#  'ma': 725,
#  'room': 310,
#  'gpai': 1667,
#  'mm': 1248,
#  'ml': 1668,
#  'mo': 426,
#  'work': 293,
#  'mi': 803,
#  'mk': 726,
#  'mj': 891,
#  'scanfing': 1671,
#  'fking': 1672,
#  'meide': 1673,
#  'my': 892,
#  'mx': 370,
#  'numcheck': 1674,
#  'addsd': 100,
#  'wang': 660,
#  'derta': 617,
#  'sushu': 189,
#  'iflet': 1675,
#  'forodd': 1676,
#  'mppx': 1677,
#  'fibonacci': 893,
#  'addss': 143,
#  'gede': 1250,
#  'end': 894,
#  'eng': 1251,
#  'verify': 1678,
#  'iiii': 504,
#  'hou': 524,
#  'answer': 481,
#  'classify': 1679,
#  'dayofm': 1252,
#  'lao': 1680,
#  'disassemble': 1681,
#  'laf': 1682,
#  'after': 525,
#  'wrong': 1683,
#  'trunc': 2178,
#  'zhengli': 1684,
#  'substract': 1901,
#  'chartonum': 1063,
#  'types': 1685,
#  'third': 505,
#  'fscan': 1253,
#  'shuliang': 2002,
#  'nmemb': 168,
#  'stri': 1686,
#  'upside': 1687,
#  'enter': 1064,
#  'strc': 1688,
#  'operate': 552,
#  'order': 284,
#  'wine': 804,
#  'oper': 1116,
#  'hebing': 316,
#  'over': 1255,
#  'imul': 54,
#  'oni': 1690,
#  'jichuan': 2160,
#  'before': 579,
#  'fit': 1691,
#  'fix': 1692,
#  ',': 2,
#  'qshang': 464,
#  'fib': 495,
#  'production': 1693,
#  'fig': 1256,
#  'crea': 1694,
#  'fim': 1066,
#  'combination': 1257,
#  'proce': 1258,
#  'zhongliu': 896,
#  'lenth': 482,
#  'qpstr': 1695,
#  'duqu': 641,
#  'unvis': 1067,
#  'l': 184,
#  'findking': 1696,
#  'alen': 897,
#  'averse': 1697,
#  'side': 1698,
#  'shirunnian': 1699,
#  'skipstring': 1700,
#  'insertb': 1701,
#  'xgy': 1702,
#  'zhaodui': 1703,
#  'zhaosushu': 1704,
#  'rt': 1705,
#  'ru': 1068,
#  'tianjie': 898,
#  'rp': 1261,
#  'rr': 619,
#  'ifprime': 1262,
#  'dst': 553,
#  're': 386,
#  'tianjis': 661,
#  'gaocheng': 1706,
#  'changdu': 620,
#  'rn': 727,
#  'size': 128,
#  'zuida': 899,
#  'mcomb': 2331,
#  'breakways': 1707,
#  'free': 175,
#  'factorii': 1708,
#  'tian': 283,
#  'tiao': 1709,
#  'houzi': 900,
#  'leapi': 2332,
#  'nta': 901,
#  'freq': 526,
#  'fangda': 1263,
#  'topjudge': 1711,
#  'subtr': 1712,
#  'atn': 1454,
#  'dayr': 1070,
#  'days': 239,
#  'filter': 1714,
#  'isi': 1715,
#  'shusu': 1264,
#  'delsp': 1265,
#  'jiaogu': 324,
#  'xun': 1716,
#  'miaoshu': 1717,
#  'huanhang': 902,
#  'shuzhi': 1718,
#  'andian': 662,
#  'grade': 979,
#  'rank': 358,
#  'hook': 1719,
#  'strncpy': 232,
#  'toy': 903,
#  'isalnum': 527,
#  'checkprime': 728,
#  'xiaojie': 2024,
#  'huanwei': 1267,
#  'qsort': 178,
#  'tot': 368,
#  'stack': 68,
#  'toj': 1720,
#  'isalpha': 319,
#  'tol': 1721,
#  'memcmp': 1268,
#  'qsortb': 1722,
#  'inputnumbers': 1723,
#  'accountdays': 1269,
#  'lanjie': 904,
#  'xj': 895,
#  'scanarray': 1724,
#  'nametimes': 1271,
#  'distance': 377,
#  'tree': 424,
#  'daysnotleap': 1725,
#  'fsubp': 729,
#  'minus': 663,
#  'mini': 1072,
#  'getarray': 905,
#  'minl': 1726,
#  'minm': 1727,
#  'minn': 621,
#  'ran': 1728,
#  'mread': 1729,
#  'minf': 1730,
#  'ming': 664,
#  'maxapple': 1731,
#  'longl': 1732,
#  'jcount': 906,
#  'mins': 1733,
#  'seek': 1734,
#  'minu': 1735,
#  'rax': 10,
#  'mulss': 141,
#  'maxx': 1273,
#  'jueduizhi': 907,
#  'chulie': 1736,
#  '-': 195,
#  'pdhw': 1737,
#  'maxj': 1738,
#  'maxh': 1274,
#  'maxi': 1073,
#  'maxn': 554,
#  'judgeline': 1074,
#  'mulsd': 92,
#  'bigprint': 1739,
#  'amnt': 1740,
#  'bianxu': 1275,
#  'disassamble': 1741,
#  'newline': 1742,
#  'pnt': 1743,
#  'doit': 730,
#  'fstp': 353,
#  'mouth': 1276,
#  'letter': 528,
#  'ostream': 38,
#  'putout': 529,
#  'inttochr': 1744,
#  'datai': 1745,
#  'dol': 1746,
#  'dom': 1075,
#  'divsd': 99,
#  'brackets': 2170,
#  'm': 157,
#  'highget': 1748,
#  'suo': 2171,
#  'bracket': 857,
#  'wordlen': 1749,
#  'jiafa': 909,
#  'sortarr': 1689,
#  'divss': 154,
#  'reserve': 483,
#  'd.': 806,
#  'd/': 622,
#  'd-': 1076,
#  'bomb': 1750,
#  'josephus': 1751,
#  'prin': 807,
#  'queen': 530,
#  'd=': 190,
#  'loaddata': 1752,
#  'sui': 1753,
#  'bigmulti': 1833,
#  'kuo': 1754,
#  'palindrome': 1277,
#  'layout': 1755,
#  'just': 1834,
#  'zhii': 1572,
#  'fooiiii': 1279,
#  'substring': 741,
#  'couts': 1756,
#  'biubiu': 1757,
#  'putapple': 732,
#  'dn': 1759,
#  'do': 1280,
#  'primjud': 1281,
#  'solutionnum': 1282,
#  'di': 1077,
#  'dg': 809,
#  'dd': 623,
#  'de': 910,
#  'stop': 1283,
#  'ceil': 406,
#  'jianli': 997,
#  'ston': 1760,
#  'zimuxiahuaxian': 1546,
#  'dx': 258,
#  'dy': 435,
#  'daopai': 2496,
#  'dt': 581,
#  'du': 733,
#  'dr': 1761,
#  'ds': 64,
#  'dp': 275,
#  'repne': 304,
#  'bat': 1762,
#  'strnu': 1286,
#  'perror': 1763,
#  'strre': 1573,
#  'bad': 1764,
#  'bac': 511,
#  'runi': 1766,
#  'strnl': 1767,
#  'ryear': 1287,
#  'bai': 1768,
#  'strncmp': 531,
#  'selectsort': 1769,
#  'strcat': 199,
#  'num': 164,
#  'clen': 1770,
#  'result': 247,
#  'fail': 69,
#  'blen': 811,
#  'best': 506,
#  'ishw': 1079,
#  'exponent': 1771,
#  'shubingpai': 1772,
#  'sortb': 1773,
#  'filename': 911,
#  'qwdm': 582,
#  'xiaochu': 1288,
#  'score': 666,
#  'isjishu': 1774,
#  'feibonaqishulie': 1775,
#  'mul': 150,
#  'sorts': 1776,
#  'ferbo': 1777,
#  'nsen': 1081,
#  'monthii': 1289,
#  'wc': 1778,
#  'wa': 1779,
#  'yuanshi': 735,
#  'wu': 1780,
#  'ws': 1781,
#  'g\\n': 1782,
#  'buzhou': 1783,
#  'huanh': 1784,
#  'toprint': 1290,
#  'exin': 1420,
#  'tushu': 1291,
#  'cos': 165,
#  'minword': 1378,
#  'opration': 1785,
#  'ill': 667,
#  'cmovs': 180,
#  'newhead': 1082,
#  'cmovl': 1786,
#  'contribution': 1787,
#  'unk': 95,
#  'com': 325,
#  'col': 252,
#  'con': 1292,
#  'and': 111,
#  'getdif': 2576,
#  'tong': 532,
#  'reorderb': 1788,
#  'height': 668,
#  'factorize': 1083,
#  'guil': 1790,
#  'fema': 914,
#  'lunhuan': 1791,
#  'puts': 91,
#  'fri': 1792,
#  'three': 1084,
#  'tiny': 1793,
#  'anyil': 1794,
#  'ifsushu': 1085,
#  'initialise': 1844,
#  'basic': 63,
#  'turntoten': 1795,
#  'minaaaa': 2167,
#  'puti': 1086,
#  'ann': 2018,
#  'atgc': 1294,
#  'suan': 669,
#  'shengxu': 1612,
#  'pri': 637,
#  'zuhe': 1798,
#  'xxx': 1799,
#  'worker': 1800,
#  'isodd': 1087,
#  'daynum': 1295,
#  'fflag': 1296,
#  'dota': 1801,
#  'child': 369,
#  'myrank': 1297,
#  'cul': 999,
#  'ascmax': 1802,
#  'slv': 1299,
#  'n': 108,
#  'mokey': 1803,
#  'paixu': 222,
#  'applesi': 1804,
#  'rema': 1805,
#  'procedure': 1806,
#  'canf': 1807,
#  'seven': 812,
#  'cons': 1808,
#  'cont': 1809,
#  'conv': 1300,
#  'juedui': 1061,
#  'ip': 916,
#  'is': 348,
#  'ir': 1389,
#  'it': 1812,
#  'ii': 204,
#  'caozuo': 1814,
#  'ohyeah': 1815,
#  'im': 387,
#  'io': 1816,
#  'in': 273,
#  'ia': 1817,
#  'ic': 1818,
#  'ib': 1819,
#  'mouse': 1820,
#  'id': 1821,
#  'if': 1301,
#  'opr': 1846,
#  'make': 496,
#  'malecnt': 917,
#  'findknot': 1822,
#  'split': 1823,
#  'outtime': 1089,
#  'qiuyu': 1825,
#  'updown': 1826,
#  'permutation': 1827,
#  'hang': 395,
#  'xinqi': 1828,
#  'hand': 918,
#  'zhiyinshu': 1302,
#  'isgraph': 1090,
#  'mianji': 425,
#  'qsorta': 1830,
#  'kid': 670,
#  'puttogether': 1303,
#  'gongxian': 1831,
#  'fucomip': 671,
#  'findpair': 1091,
#  'getsum': 1832,
#  'thi': 1304,
#  'the': 1305,
#  'left': 672,
#  'birth': 1259,
#  'dosomething': 1278,
#  'sentence': 484,
#  'photo': 1835,
#  'qianshou': 1092,
#  'distribute': 1836,
#  'zerocol': 1306,
#  'rns': 1837,
#  'repick': 1838,
#  'findlen': 850,
#  'yes': 583,
#  'mymin': 2020,
#  'countl': 1840,
#  'handshake': 1841,
#  'han': 1308,
#  'shumu': 1842,
#  'shoui': 1843,
#  'spread': 465,
#  'board': 262,
#  'zhisu': 1309,
#  'has': 1845,
#  'opt': 1310,
#  'opp': 1311,
#  'panrun': 1088,
#  'survival': 1847,
#  'mutiply': 1829,
#  'ope': 1312,
#  'getaverage': 1849,
#  'valueii': 1313,
#  'getf': 1850,
#  'judge': 202,
#  'sxpl': 1448,
#  'freopen': 920,
#  'fangjungen': 1852,
#  'qiumax': 1314,
#  'right': 585,
#  'old': 533,
#  'deal': 407,
#  'people': 408,
#  'maxii': 1093,
#  'zch': 1315,
#  'maxim': 1853,
#  'rever': 1854,
#  'born': 1094,
#  'hypot': 1855,
#  'statistic': 1856,
#  'rangestr': 1857,
#  'doublesort': 1858,
#  'cnt': 290,
#  'txt': 1316,
#  'trace': 2023,
#  'for': 1317,
#  'bottom': 1859,
#  'rezero': 1860,
#  'judy': 1956,
#  'iszhishu': 1318,
#  'paib': 1861,
#  'allocate': 1862,
#  'fob': 1863,
#  'foo': 1095,
#  'hsb': 1865,
#  'peek': 436,
#  'plu': 921,
#  'hsa': 1867,
#  'posi': 1868,
#  'ascanf': 1869,
#  'yin': 1374,
#  'post': 1319,
#  'lianjie': 1871,
#  'plusbig': 1872,
#  'movenum': 1873,
#  'emp': 1765,
#  'plug': 1875,
#  'chuan': 1320,
#  'movsd': 51,
#  'months': 586,
#  'tshang': 673,
#  'o': 279,
#  'plus': 1876,
#  'movsx': 82,
#  'zui': 1877,
#  'movss': 78,
#  'movsq': 311,
#  'subv': 1878,
#  'subs': 1096,
#  'fanxu': 486,
#  'float': 158,
#  'sol': 1097,
#  'two': 640,
#  'down': 624,
#  'pair': 2028,
#  'ppp': 813,
#  'ppt': 1880,
#  'jisuan': 476,
#  'baifang': 814,
#  'gir': 1881,
#  'imim': 815,
#  'imin': 1882,
#  'transform': 1321,
#  'fight': 625,
#  'joseph': 1099,
#  'way': 409,
#  'checkrun': 1883,
#  'monthlength': 1322,
#  'noshowpos': 922,
#  'head': 296,
#  'medium': 736,
#  'd\\nz': 626,
#  'form': 588,
#  'ganster': 1884,
#  'converse': 1323,
#  'analyse': 1885,
#  'd\\ns': 627,
#  'lenofr': 923,
#  'd\\nq': 628,
#  'moveforward': 1887,
#  'dump': 1888,
#  'rowmax': 1324,
#  'isit': 1325,
#  'combinestr': 1889,
#  'devide': 534,
#  'maximum': 924,
#  'leapyeari': 1890,
#  'yueshu': 1891,
#  'yuandan': 1326,
#  'xunzhao': 1398,
#  'isin': 1327,
#  'delete': 1328,
#  'rnfeb': 1893,
#  'exist': 1894,
#  'mdays': 1329,
#  'allfilled': 1895,
#  'qiw': 674,
#  'check': 217,
#  'shit': 1330,
#  'ni': 1896,
#  'nm': 320,
#  'nn': 925,
#  'floor': 253,
#  'na': 453,
#  'nf': 816,
#  'getstr': 1331,
#  'nx': 1132,
#  'ny': 1332,
#  'test': 61,
#  'nu': 1136,
#  'node': 243,
#  'nixu': 629,
#  'findmax': 630,
#  'cor': 2570,
#  'ntos': 1899,
#  'sqr': 1231,
#  'xiaojian': 507,
#  'squ': 1900,
#  'pingguo': 1562,
#  'discharge': 1902,
#  'pseudo': 1903,
#  'together': 737,
#  'time': 1100,
#  'push': 55,
#  'oppoorder': 1429,
#  'getint': 2373,
#  'primei': 927,
#  'danci': 1905,
#  'chain': 1906,
#  '.lf\\n': 1907,
#  'setin': 1813,
#  'maopao': 928,
#  'battle': 1333,
#  'shot': 2033,
#  'prop': 1943,
#  'row': 241,
#  'inverse': 817,
#  'zong': 1909,
#  'juzheng': 1910,
#  'charge': 1911,
#  'isspace': 675,
#  'eliminate': 2347,
#  'division': 1335,
#  'string': 929,
#  'hangxiao': 1912,
#  'nihao': 1913,
#  'arraycout': 1914,
#  'word': 203,
#  'birev': 1336,
#  'minute': 1337,
#  'cool': 1915,
#  'dil': 234,
#  'jisuanb': 1916,
#  'level': 555,
#  'die': 930,
#  'rechange': 1101,
#  'leave': 70,
#  'p': 171,
#  'diy': 1338,
#  'team': 676,
#  'quick': 1339,
#  'div': 132,
#  'setup': 1669,
#  'dir': 931,
#  'dis': 249,
#  'upper': 1340,
#  'mn': 1670,
#  'core': 1866,
#  'itruth': 1102,
#  'addauthor': 1917,
#  'printfing': 1918,
#  'sign': 378,
#  'setnle': 125,
#  'bg': 1919,
#  'mgpa': 1920,
#  'run': 285,
#  'mhang': 1341,
#  'bacteria': 589,
#  'baka': 1921,
#  'adds': 1922,
#  'sheng': 1423,
#  'chufa': 1924,
#  'orde': 1925,
#  'lefts': 1926,
#  'minnum': 1927,
#  'addd': 1928,
#  'addc': 1929,
#  'mergesort': 932,
#  'fmax': 739,
#  'houc': 1930,
#  'yiwei': 1342,
#  'pause': 2527,
#  'bj': 1932,
#  'newnode': 1933,
#  '[': 5,
#  'change': 206,
#  'boy': 278,
#  'dec': 973,
#  'shift': 497,
#  'strlw': 1343,
#  'mincol': 933,
#  'example': 1249,
#  'queue': 274,
#  'whatmark': 1934,
#  'hubing': 1935,
#  '(': 36,
#  'convertor': 1936,
#  'turnback': 1937,
#  'maxnum': 1103,
#  'checkbegin': 740,
#  'judgechar': 1938,
#  'ls': 1104,
#  'ipt': 1345,
#  'atoten': 1939,
#  'fenjie': 312,
#  'setfill': 1515,
#  'deletev': 1870,
#  'monthv': 1942,
#  'prove': 1346,
#  'memory': 934,
#  'swep': 1944,
#  'deletes': 1874,
#  'dudu': 1347,
#  'd\\n': 147,
#  'reorder': 1348,
#  'judgenum': 1945,
#  'separy': 1946,
#  'countnum': 1349,
#  'getadd': 1947,
#  'rtrt': 1948,
#  'distribution': 2635,
#  'maxasc': 1949,
#  'lian': 2153,
#  'fly': 1950,
#  'numberv': 2192,
#  'fuction': 1350,
#  'judm': 1951,
#  'cas': 1952,
#  'car': 1953,
#  'cap': 1954,
#  'flu': 818,
#  'cat': 1537,
#  'zhao': 463,
#  'cao': 1351,
#  'can': 677,
#  'cal': 269,
#  'showpos': 935,
#  'trans': 308,
#  'fld': 346,
#  'fenjieyinshi': 1957,
#  'stream': 288,
#  'spp': 1352,
#  'fuck': 590,
#  'sample': 1193,
#  'erchashu': 936,
#  'refine': 1353,
#  'isequal': 1354,
#  'feof': 631,
#  'spe': 1958,
#  'strncat': 535,
#  'fpg': 1106,
#  'clearerr': 1355,
#  's=': 371,
#  'ping': 1107,
#  'idiv': 112,
#  'write': 937,
#  'huiwenjud': 1959,
#  'pure': 742,
#  'kingmonkey': 1960,
#  'saintseiya': 2505,
#  'divider': 1356,
#  'map': 297,
#  'product': 1357,
#  'mat': 313,
#  'divi': 1961,
#  'max': 188,
#  'divd': 1962,
#  'produce': 1108,
#  'uint': 256,
#  'date': 305,
#  'zimu': 427,
#  'data': 237,
#  'grow': 938,
#  'ld\\n': 447,
#  'man': 454,
#  'sz': 260,
#  'sy': 1964,
#  'sx': 1109,
#  'calday': 1358,
#  'varieties': 786,
#  'joint': 1965,
#  'ss': 277,
#  'sr': 678,
#  'sq': 557,
#  'sw': 939,
#  'su': 240,
#  'st': 227,
#  'q': 196,
#  'sj': 591,
#  'sh': 1966,
#  'so': 1360,
#  'sm': 1160,
#  'sl': 1110,
#  'sc': 743,
#  'sb': 819,
#  'sa': 679,
#  'sf': 1968,
#  'sd': 1361,
#  'yearv': 1969,
#  'years': 1362,
#  'course': 493,
#  'yeari': 558,
#  'tashisushu': 1363,
#  'quanganran': 1970,
#  'numchange': 1971,
#  'jie': 940,
#  'group': 618,
#  'djt': 632,
#  'istrue': 1972,
#  'jia': 941,
#  'nima': 1973,
#  'colmin': 1974,
#  'judgebegin': 1975,
#  'mail': 1111,
#  'main': 173,
#  'monkeyking': 1976,
#  'getlinked': 1977,
#  'killer': 1112,
#  'commoninteger': 1978,
#  'inits': 1979,
#  'half': 1980,
#  'not': 270,
#  'mlie': 1365,
#  'now': 487,
#  'nop': 88,
#  'nor': 1981,
#  'shu': 433,
#  'term': 1983,
#  'name': 401,
#  'jiaodian': 1984,
#  'printarr': 1985,
#  'revers': 1986,
#  'isnum': 1987,
#  'maxlocate': 1988,
#  'dawang': 1989,
#  'h': 233,
#  'square': 559,
#  'ee': 942,
#  'ec': 1990,
#  'lencount': 680,
#  'ex': 744,
#  'year': 244,
#  'girl': 326,
#  'eq': 681,
#  'er': 1991,
#  'fsubrp': 1992,
#  'strbigint': 1993,
#  'fopen': 1366,
#  'factors': 1230,
#  'fw': 1461,
#  'zuobian': 1367,
#  'increase': 820,
#  'godbah': 1994,
#  'checkstr': 1995,
#  'ishuiwen': 745,
#  'isgoodsubstr': 2538,
#  'factorsii': 1997,
#  'tmpl': 634,
#  'youxiu': 1368,
#  'antitone': 1369,
#  'ori': 1115,
#  'rlt': 1998,
#  'byte': 75,
#  'xiaoshi': 635,
#  'fixed': 163,
#  'qm': 1370,
#  'tries': 731,
#  'turn': 341,
#  'routey': 943,
#  'routex': 944,
#  'place': 682,
#  'islower': 508,
#  'dayofy': 2000,
#  'ture': 2001,
#  'isupper': 592,
#  'yue': 746,
#  'jianyan': 1254,
#  'first': 294,
#  'origin': 849,
#  'xi': 945,
#  'numb': 762,
#  'xl': 1371,
#  'zai': 2004,
#  'xb': 560,
#  'xa': 683,
#  'xg': 1372,
#  'one': 946,
#  'mingliu': 2202,
#  'xx': 437,
#  'reslove': 2005,
#  'carry': 2006,
#  'xs': 1117,
#  'array': 230,
#  'isidentifor': 2362,
#  'xu': 1069,
#  'yid': 2008,
#  'breed': 856,
#  'weekdays': 947,
#  'msort': 2009,
#  'sear': 2051,
#  'fraction': 2011,
#  'memo': 2012,
#  'houzhui': 2013,
#  'twopoint': 2014,
#  'hui': 300,
#  'msize': 684,
#  'germ': 1375,
#  'zhuanhuan': 747,
#  'daodan': 821,
#  'copy': 636,
#  'than': 1376,
#  'firstout': 948,
#  'searchjoint': 1284,
#  'r': 218,
#  'apples': 1377,
#  'outcome': 912,
#  'decompose': 1379,
#  'pre': 913,
#  'rowset': 2016,
#  'ana': 2017,
#  'pro': 915,
#  'ano': 822,
#  'delim': 362,
#  'prt': 593,
#  'ans': 212,
#  'sar': 59,
#  'chengfa': 2019,
#  'kuso': 1118,
#  'fsize': 685,
#  'oddnum': 1839,
#  'take': 951,
#  'destroy': 952,
#  'noti': 2021,
#  'findoutmax': 2022,
#  'begin': 488,
#  'boyi': 2367,
#  'multiple': 1119,
#  'ulong': 359,
#  'normal': 953,
#  'buffer': 954,
#  'paic': 1864,
#  'dicide': 2025,
#  'qishu': 2026,
#  'detect': 2053,
#  'putapp': 2027,
#  'multiply': 587,
#  'setle': 216,
#  ']': 6,
#  ...}

# %%
data =[]
unk_count = 0
for word in corpus:
    if word in dictionary:
        index = dictionary[word]
    else:
        index = 0
        unk_count = unk_count+1
    data.append(index)
    count[0][1] =unk_count

# %%
data
# Out:
# [55,
#  7,
#  1,
#  3,
#  7,
#  2,
#  42,
#  1,
#  26,
#  42,
#  2,
#  1,
#  3,
#  10,
#  2,
#  50,
#  11,
#  1,
#  3,
#  5,
#  7,
#  4,
#  9,
#  6,
#  2,
#  10,
#  1,
#  49,
#  8,
#  2,
#  8,
#  1,
#  23,
#  10,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  34,
#  2,
#  10,
#  1,
#  3,
#  29,
#  2,
#  28,
#  107,
#  1,
#  18,
#  20,
#  11,
#  11,
#  74,
#  11,
#  11,
#  46,
#  25,
#  25,
#  36,
#  53,
#  43,
#  35,
#  1,
#  3,
#  31,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  54,
#  15,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  59,
#  8,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  15,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  12,
#  15,
#  2,
#  15,
#  1,
#  12,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  26,
#  8,
#  2,
#  15,
#  1,
#  61,
#  8,
#  2,
#  8,
#  1,
#  48,
#  13,
#  3,
#  31,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  54,
#  15,
#  1,
#  59,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  59,
#  8,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  15,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  32,
#  15,
#  2,
#  1,
#  12,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  26,
#  8,
#  2,
#  15,
#  1,
#  61,
#  8,
#  2,
#  8,
#  1,
#  48,
#  16,
#  13,
#  3,
#  31,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  54,
#  15,
#  1,
#  23,
#  8,
#  2,
#  5,
#  14,
#  4,
#  30,
#  6,
#  1,
#  59,
#  8,
#  2,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  59,
#  8,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  15,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  32,
#  15,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  26,
#  8,
#  2,
#  15,
#  1,
#  61,
#  8,
#  2,
#  8,
#  1,
#  48,
#  16,
#  13,
#  3,
#  37,
#  2,
#  28,
#  1,
#  3,
#  29,
#  2,
#  28,
#  1,
#  18,
#  20,
#  11,
#  11,
#  46,
#  19,
#  19,
#  19,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  36,
#  20,
#  11,
#  11,
#  63,
#  38,
#  19,
#  21,
#  2,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  43,
#  2,
#  21,
#  83,
#  22,
#  35,
#  1,
#  27,
#  13,
#  3,
#  37,
#  2,
#  28,
#  1,
#  3,
#  29,
#  2,
#  28,
#  1,
#  18,
#  20,
#  11,
#  11,
#  46,
#  19,
#  19,
#  19,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  36,
#  20,
#  11,
#  11,
#  63,
#  38,
#  19,
#  21,
#  2,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  43,
#  2,
#  21,
#  83,
#  22,
#  35,
#  1,
#  27,
#  13,
#  3,
#  31,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  54,
#  15,
#  1,
#  23,
#  8,
#  2,
#  5,
#  14,
#  4,
#  30,
#  6,
#  1,
#  59,
#  8,
#  2,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  59,
#  8,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  15,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  32,
#  15,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  26,
#  8,
#  2,
#  15,
#  1,
#  61,
#  8,
#  2,
#  8,
#  1,
#  48,
#  16,
#  13,
#  3,
#  37,
#  2,
#  28,
#  1,
#  3,
#  29,
#  2,
#  28,
#  1,
#  18,
#  20,
#  11,
#  11,
#  46,
#  19,
#  19,
#  19,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  36,
#  20,
#  11,
#  11,
#  63,
#  38,
#  19,
#  21,
#  2,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  43,
#  2,
#  21,
#  83,
#  22,
#  35,
#  1,
#  27,
#  13,
#  3,
#  37,
#  2,
#  28,
#  1,
#  3,
#  29,
#  2,
#  28,
#  1,
#  18,
#  20,
#  11,
#  11,
#  46,
#  19,
#  19,
#  19,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  36,
#  20,
#  11,
#  11,
#  63,
#  38,
#  19,
#  21,
#  2,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  43,
#  2,
#  21,
#  83,
#  22,
#  35,
#  1,
#  27,
#  13,
#  3,
#  31,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  54,
#  15,
#  1,
#  59,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  59,
#  8,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  15,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  32,
#  15,
#  2,
#  1,
#  12,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  26,
#  8,
#  2,
#  15,
#  1,
#  61,
#  8,
#  2,
#  8,
#  1,
#  48,
#  16,
#  13,
#  3,
#  31,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  54,
#  15,
#  1,
#  23,
#  8,
#  2,
#  5,
#  14,
#  4,
#  30,
#  6,
#  1,
#  59,
#  8,
#  2,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  59,
#  8,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  15,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  32,
#  15,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  26,
#  8,
#  2,
#  15,
#  1,
#  61,
#  8,
#  2,
#  8,
#  1,
#  48,
#  16,
#  13,
#  3,
#  37,
#  2,
#  28,
#  1,
#  3,
#  29,
#  2,
#  28,
#  1,
#  18,
#  20,
#  11,
#  11,
#  46,
#  19,
#  19,
#  19,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  36,
#  20,
#  11,
#  11,
#  63,
#  38,
#  19,
#  21,
#  2,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  43,
#  2,
#  21,
#  83,
#  22,
#  35,
#  1,
#  27,
#  13,
#  3,
#  37,
#  2,
#  28,
#  1,
#  3,
#  29,
#  2,
#  28,
#  1,
#  18,
#  20,
#  11,
#  11,
#  46,
#  19,
#  19,
#  19,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  36,
#  20,
#  11,
#  11,
#  63,
#  38,
#  19,
#  21,
#  2,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  25,
#  43,
#  2,
#  21,
#  83,
#  22,
#  35,
#  1,
#  27,
#  13,
#  3,
#  31,
#  2,
#  5,
#  7,
#  4,
#  9,
#  6,
#  1,
#  3,
#  15,
#  2,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  54,
#  15,
#  1,
#  23,
#  8,
#  2,
#  5,
#  14,
#  4,
#  30,
#  6,
#  1,
#  59,
#  8,
#  2,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  59,
#  8,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  15,
#  1,
#  3,
#  15,
#  2,
#  8,
#  1,
#  32,
#  15,
#  2,
#  1,
#  26,
#  15,
#  2,
#  8,
#  1,
#  3,
#  8,
#  2,
#  31,
#  1,
#  26,
#  8,
#  2,
#  15,
#  1,
#  61,
#  8,
#  2,
#  8,
#  1,
#  48,
#  16,
#  13,
#  3,
#  37,
#  2,
#  1,
#  3,
#  29,
#  2,
#  28,
#  1,
#  18,
#  20,
#  11,
#  11,
#  46,
#  19,
#  19,
#  19,
#  20,
#  11,
#  11,
#  21,
#  45,
#  19,
#  21,
#  25,
#  ...]

# %%
corpus
# Out:
# ['push',
#  'rbp',
#  '$',
#  'mov',
#  'rbp',
#  ',',
#  'rsp',
#  '$',
#  'sub',
#  'rsp',
#  ',',
#  '$',
#  'mov',
#  'rax',
#  ',',
#  'fs',
#  ':',
#  '$',
#  'mov',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  ',',
#  'rax',
#  '$',
#  'xor',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'lea',
#  'rax',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'rsi',
#  ',',
#  'rax',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  'edata',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'istream',
#  ':',
#  ':',
#  'operator',
#  '>',
#  '>',
#  '(',
#  'int',
#  '&',
#  ')',
#  '$',
#  'mov',
#  'ecx',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'imul',
#  'edx',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'add',
#  'edx',
#  ',',
#  'edx',
#  '$',
#  'add',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sub',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'test',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'jnz',
#  'loc',
#  'mov',
#  'ecx',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'imul',
#  'edx',
#  '$',
#  'sar',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'shl',
#  'edx',
#  ',',
#  '$',
#  'add',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sub',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'test',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'jnz',
#  'short',
#  'loc',
#  'mov',
#  'ecx',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'imul',
#  'edx',
#  '$',
#  'lea',
#  'eax',
#  ',',
#  '[',
#  'rdx',
#  '+',
#  'rcx',
#  ']',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'shl',
#  'edx',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sub',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'test',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'jnz',
#  'short',
#  'loc',
#  'mov',
#  'esi',
#  ',',
#  'offset',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'operator',
#  '<',
#  '<',
#  '<',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '(',
#  'std',
#  ':',
#  ':',
#  'basic',
#  'ostream',
#  '<',
#  'char',
#  ',',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '&',
#  ',',
#  'char',
#  'const',
#  '*',
#  ')',
#  '$',
#  'jmp',
#  'loc',
#  'mov',
#  'esi',
#  ',',
#  'offset',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'operator',
#  '<',
#  '<',
#  '<',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '(',
#  'std',
#  ':',
#  ':',
#  'basic',
#  'ostream',
#  '<',
#  'char',
#  ',',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '&',
#  ',',
#  'char',
#  'const',
#  '*',
#  ')',
#  '$',
#  'jmp',
#  'loc',
#  'mov',
#  'ecx',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'imul',
#  'edx',
#  '$',
#  'lea',
#  'eax',
#  ',',
#  '[',
#  'rdx',
#  '+',
#  'rcx',
#  ']',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'shl',
#  'edx',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sub',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'test',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'jnz',
#  'short',
#  'loc',
#  'mov',
#  'esi',
#  ',',
#  'offset',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'operator',
#  '<',
#  '<',
#  '<',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '(',
#  'std',
#  ':',
#  ':',
#  'basic',
#  'ostream',
#  '<',
#  'char',
#  ',',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '&',
#  ',',
#  'char',
#  'const',
#  '*',
#  ')',
#  '$',
#  'jmp',
#  'loc',
#  'mov',
#  'esi',
#  ',',
#  'offset',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'operator',
#  '<',
#  '<',
#  '<',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '(',
#  'std',
#  ':',
#  ':',
#  'basic',
#  'ostream',
#  '<',
#  'char',
#  ',',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '&',
#  ',',
#  'char',
#  'const',
#  '*',
#  ')',
#  '$',
#  'jmp',
#  'loc',
#  'mov',
#  'ecx',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'imul',
#  'edx',
#  '$',
#  'sar',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'shl',
#  'edx',
#  ',',
#  '$',
#  'add',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sub',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'test',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'jnz',
#  'short',
#  'loc',
#  'mov',
#  'ecx',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'imul',
#  'edx',
#  '$',
#  'lea',
#  'eax',
#  ',',
#  '[',
#  'rdx',
#  '+',
#  'rcx',
#  ']',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'shl',
#  'edx',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sub',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'test',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'jnz',
#  'short',
#  'loc',
#  'mov',
#  'esi',
#  ',',
#  'offset',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'operator',
#  '<',
#  '<',
#  '<',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '(',
#  'std',
#  ':',
#  ':',
#  'basic',
#  'ostream',
#  '<',
#  'char',
#  ',',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '&',
#  ',',
#  'char',
#  'const',
#  '*',
#  ')',
#  '$',
#  'jmp',
#  'loc',
#  'mov',
#  'esi',
#  ',',
#  'offset',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'operator',
#  '<',
#  '<',
#  '<',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '(',
#  'std',
#  ':',
#  ':',
#  'basic',
#  'ostream',
#  '<',
#  'char',
#  ',',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  '>',
#  '&',
#  ',',
#  'char',
#  'const',
#  '*',
#  ')',
#  '$',
#  'jmp',
#  'loc',
#  'mov',
#  'ecx',
#  ',',
#  '[',
#  'rbp',
#  '+',
#  'var',
#  ']',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'imul',
#  'edx',
#  '$',
#  'lea',
#  'eax',
#  ',',
#  '[',
#  'rdx',
#  '+',
#  'rcx',
#  ']',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sar',
#  'eax',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'mov',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'shl',
#  'edx',
#  ',',
#  '$',
#  'sub',
#  'edx',
#  ',',
#  'eax',
#  '$',
#  'mov',
#  'eax',
#  ',',
#  'ecx',
#  '$',
#  'sub',
#  'eax',
#  ',',
#  'edx',
#  '$',
#  'test',
#  'eax',
#  ',',
#  'eax',
#  '$',
#  'jnz',
#  'short',
#  'loc',
#  'mov',
#  'esi',
#  ',',
#  '$',
#  'mov',
#  'edi',
#  ',',
#  'offset',
#  '$',
#  'call',
#  'std',
#  ':',
#  ':',
#  'operator',
#  '<',
#  '<',
#  '<',
#  'std',
#  ':',
#  ':',
#  'char',
#  'traits',
#  '<',
#  'char',
#  '>',
#  ...]

# %%
# import modules & set up logging
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
model = Word2Vec(sentences=corpus,size=128,batch_words=128,iter=10,workers=6)
# Out:
# 2017-11-02 22:04:20,622 : INFO : collecting all words and their counts
# 2017-11-02 22:04:20,624 : WARNING : Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <type 'str'>.
# 2017-11-02 22:04:20,625 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-11-02 22:04:20,633 : INFO : PROGRESS: at sentence #10000, processed 22743 words, keeping 35 word types
# 2017-11-02 22:04:20,640 : INFO : PROGRESS: at sentence #20000, processed 45222 words, keeping 36 word types
# 2017-11-02 22:04:20,648 : INFO : PROGRESS: at sentence #30000, processed 67806 words, keeping 36 word types
# 2017-11-02 22:04:20,656 : INFO : PROGRESS: at sentence #40000, processed 90623 words, keeping 37 word types
# 2017-11-02 22:04:20,664 : INFO : PROGRESS: at sentence #50000, processed 113432 words, keeping 37 word types
# 2017-11-02 22:04:20,672 : INFO : PROGRESS: at sentence #60000, processed 136198 words, keeping 37 word types
# 2017-11-02 22:04:20,680 : INFO : PROGRESS: at sentence #70000, processed 158880 words, keeping 37 word types
# 2017-11-02 22:04:20,688 : INFO : PROGRESS: at sentence #80000, processed 181770 words, keeping 37 word types
# 2017-11-02 22:04:20,699 : INFO : PROGRESS: at sentence #90000, processed 204399 words, keeping 37 word types
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips): 
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# ('data:', ['push', 'rbp', '$', 'mov', 'rbp', ',', 'rsp', '$'])
#
# with num_skips = 2 and skip_window = 1:
# ('    batch:', ['rbp', 'rbp', '$', '$', 'mov', 'mov', 'rbp', 'rbp'])
# ('    labels:', ['$', 'push', 'mov', 'rbp', '$', 'rbp', ',', 'mov'])
#
# with num_skips = 4 and skip_window = 2:
# ('    batch:', ['$', '$', '$', '$', 'mov', 'mov', 'mov', 'mov'])
# ('    labels:', ['rbp', 'mov', 'push', 'rbp', 'rbp', 'rbp', ',', '$'])

# %%
len(dictionary),len(reverse_dictionary),len(corpus),len(data)
# Out:
# (2652, 2652, 42846328, 42846328)

# %%
vocabulary_size = len(dictionary)
batch_size = 128
embedding_size = 128 
skip_window = 1 
num_skips = 2
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default():
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
    optimizer = tf.train.AdagradOptimizer(0.005).minimize(loss)
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    
num_steps = 1000001
data_index =0

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
           batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, cost = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += cost
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.576579
# Average loss at step 2000: 4.179501
# Average loss at step 4000: 2.703701
# Average loss at step 6000: 2.112090
# Average loss at step 8000: 1.889739
# Average loss at step 10000: 2.277381
# Average loss at step 12000: 2.235256
# Average loss at step 14000: 1.948352
# Average loss at step 922000: 1.420909
# Average loss at step 924000: 1.434683
# Average loss at step 926000: 1.420742
# Average loss at step 928000: 1.414421
# Average loss at step 930000: 1.422551
# Average loss at step 932000: 1.412006
# Average loss at step 934000: 1.451688
# Average loss at step 936000: 1.407164
# Average loss at step 938000: 1.382167
# Average loss at step 940000: 1.344331
# Average loss at step 942000: 1.358061
# Average loss at step 944000: 1.458602
# Average loss at step 946000: 1.501254
# Average loss at step 948000: 1.439105
# Average loss at step 950000: 1.463090
# Average loss at step 952000: 1.433152
# Average loss at step 954000: 1.440352
# Average loss at step 956000: 1.441640
# Average loss at step 958000: 1.426576
# Average loss at step 960000: 1.424336
# Average loss at step 962000: 1.447761
# Average loss at step 964000: 1.480450
# Average loss at step 966000: 1.442395
# Average loss at step 968000: 1.483635
# Average loss at step 970000: 1.415072
# Average loss at step 972000: 1.429526
# Average loss at step 974000: 1.420760
# Average loss at step 976000: 1.409265
# Average loss at step 978000: 1.407799
# Average loss at step 980000: 1.278043
# Average loss at step 982000: 1.262230
# Average loss at step 984000: 1.248885
# Average loss at step 986000: 1.266695
# Average loss at step 988000: 1.225120
# Average loss at step 990000: 1.281572
# Average loss at step 992000: 1.440772
# Average loss at step 994000: 1.426001
# Average loss at step 996000: 1.434857
# Average loss at step 998000: 1.424409
# Average loss at step 1000000: 1.427884

# %%
final_embeddings.shape
# Out:
# (2652, 128)

# %%
from sklearn.manifold import TSNE

# %%
num_points = 1000

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
from matplotlib import pylab
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        plt.scatter(x, y)
        plt.annotate(label, xy=(x, y), xytext=(3,2), textcoords='offset points',
                     ha='right', va='bottom')
    plt.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
o,p= two_d_embeddings[1,:]

# %%
[reverse_dictionary[j] for j in range(1,num_points+1)]
# Out:
# ['$',
#  ',',
#  'mov',
#  '+',
#  '[',
#  ']',
#  'rbp',
#  'eax',
#  'var',
#  'rax',
#  ':',
#  'add',
#  'loc',
#  'rdx',
#  'edx',
#  'short',
#  'cmp',
#  'call',
#  '<',
#  'std',
#  'char',
#  '*',
#  'lea',
#  'cdqe',
#  '>',
#  'sub',
#  'jmp',
#  'offset',
#  'edi',
#  'rcx',
#  'ecx',
#  'shl',
#  'movsxd',
#  'rsi',
#  ')',
#  '(',
#  'esi',
#  'ostream',
#  'rdi',
#  's',
#  'al',
#  'rsp',
#  '&',
#  'jz',
#  'traits',
#  'operator',
#  'movzx',
#  'jnz',
#  'xor',
#  'fs',
#  'movsd',
#  'jge',
#  'int',
#  'imul',
#  'push',
#  'jg',
#  'jle',
#  'ptr',
#  'sar',
#  'printf',
#  'test',
#  'scanf',
#  'basic',
#  'ds',
#  'retn',
#  'format',
#  'chk',
#  'stack',
#  'fail',
#  'leave',
#  'locret',
#  'rbx',
#  'cs',
#  'istream',
#  'byte',
#  'd',
#  'c',
#  'movss',
#  'pxor',
#  'qword',
#  'dword',
#  'movsx',
#  'const',
#  'pop',
#  'jl',
#  'endl',
#  'strlen',
#  'nop',
#  'dl',
#  'putchar',
#  'puts',
#  'mulsd',
#  'movapd',
#  'shr',
#  'unk',
#  'ucomisd',
#  'ebx',
#  'subsd',
#  'divsd',
#  'addsd',
#  'rep',
#  'stosq',
#  'a',
#  'jbe',
#  'x',
#  'gets',
#  'edata',
#  'n',
#  'js',
#  'src',
#  'and',
#  'idiv',
#  'cdq',
#  'base',
#  'getchar',
#  'sqrt',
#  'dest',
#  'double',
#  'void',
#  'setz',
#  'setnz',
#  'i',
#  'memset',
#  'ios',
#  'setnle',
#  'long',
#  'jb',
#  'size',
#  'ucomiss',
#  'neg',
#  'jnb',
#  'div',
#  'getline',
#  'cl',
#  'malloc',
#  'strcmp',
#  'strcpy',
#  'f',
#  'jp',
#  'ja',
#  'mulss',
#  'subss',
#  'addss',
#  'b',
#  'lf',
#  'get',
#  'd\\n',
#  'movq',
#  'xorpd',
#  'mul',
#  'asc',
#  'j',
#  'y',
#  'divss',
#  'movaps',
#  'pow',
#  'm',
#  'float',
#  'k',
#  'jns',
#  'off',
#  'setprecision',
#  'fixed',
#  'num',
#  'cos',
#  'ax',
#  'cqo',
#  'nmemb',
#  'nptr',
#  'c=',
#  'p',
#  'sum',
#  'main',
#  'andpd',
#  'free',
#  's\\n',
#  't',
#  'qsort',
#  'compar',
#  'cmovs',
#  'str',
#  'reverse',
#  'sort',
#  'l',
#  'xorps',
#  'setl',
#  'setnb',
#  'max',
#  'sushu',
#  'd=',
#  'haystack',
#  'or',
#  'stu',
#  'temp',
#  '-',
#  'q',
#  '=',
#  'setnbe',
#  'strcat',
#  'g',
#  'len',
#  'judge',
#  'word',
#  'ii',
#  'needle',
#  'change',
#  'ld',
#  'prime',
#  'c\\n',
#  'iii',
#  'sil',
#  'ans',
#  'print',
#  'andps',
#  'atoi',
#  'setle',
#  'check',
#  'r',
#  'lf\\n',
#  'min',
#  'huiwen',
#  'paixu',
#  'setnl',
#  'swap',
#  'e',
#  'count',
#  'st',
#  'input',
#  'total',
#  'array',
#  'calloc',
#  'strncpy',
#  'h',
#  'dil',
#  'flag',
#  'w',
#  'data',
#  'z',
#  'days',
#  'su',
#  'row',
#  'student',
#  'node',
#  'year',
#  'leap',
#  'day',
#  'result',
#  'apple',
#  'dis',
#  'panduan',
#  'strstr',
#  'col',
#  'floor',
#  'fun',
#  'output',
#  'uint',
#  'creat',
#  'dx',
#  'move',
#  'sz',
#  'number',
#  'board',
#  'line',
#  'length',
#  'find',
#  'out',
#  'read',
#  'match',
#  'cal',
#  'not',
#  'tmp',
#  'movd',
#  'in',
#  'queue',
#  'dp',
#  'isprime',
#  'ss',
#  'boy',
#  'o',
#  'cmovnz',
#  'shuchu',
#  'month',
#  'tian',
#  'order',
#  'run',
#  'search',
#  'setnp',
#  'stream',
#  'combine',
#  'cnt',
#  'bubble',
#  'atof',
#  'work',
#  'first',
#  'shuru',
#  'head',
#  'map',
#  'pd',
#  'function',
#  'hui',
#  'u',
#  'person',
#  'toupper',
#  'repne',
#  'date',
#  'scasb',
#  'put',
#  'trans',
#  'area',
#  'room',
#  'movsq',
#  'fenjie',
#  'mat',
#  'compare',
#  'point',
#  'hebing',
#  'money',
#  'res',
#  'isalpha',
#  'nm',
#  'tj',
#  'ld=',
#  'tianji',
#  'jiaogu',
#  'com',
#  'girl',
#  'runnian',
#  'matrix',
#  'qiwang',
#  'an',
#  'v',
#  'dijitian',
#  'la',
#  'exchange',
#  'qw',
#  'power',
#  'female',
#  'mon',
#  'zhishu',
#  'func',
#  'turn',
#  'exit',
#  'status',
#  'times',
#  'divide',
#  'fld',
#  'scan',
#  'is',
#  'male',
#  'log',
#  'fmod',
#  'strchr',
#  'fstp',
#  'pai',
#  'del',
#  'insert',
#  'memcpy',
#  'rank',
#  'ulong',
#  'f\\n',
#  'sen',
#  'delim',
#  'aa',
#  'create',
#  'arrange',
#  'strtok',
#  'calc',
#  'tot',
#  'child',
#  'mx',
#  's=',
#  'solve',
#  'win',
#  'lb',
#  'qq',
#  'qi',
#  'distance',
#  'sign',
#  'to',
#  'convert',
#  'state',
#  'ioinit',
#  'shuzu',
#  'factor',
#  'he',
#  're',
#  'im',
#  'up',
#  'ji',
#  'tem',
#  'king',
#  'chang',
#  'stud',
#  'px',
#  'hang',
#  'of',
#  'arr',
#  'arg',
#  'bb',
#  'calculate',
#  'name',
#  'pat',
#  'aaa',
#  'grids',
#  'hw',
#  'ceil',
#  'deal',
#  'people',
#  'way',
#  'pos',
#  'jishu',
#  'ys',
#  'lie',
#  'ignore',
#  'patient',
#  'zhi',
#  'zh',
#  'from',
#  'ren',
#  'zfc',
#  'ch',
#  'know',
#  'second',
#  'tree',
#  'mianji',
#  'mo',
#  'zimu',
#  'qj',
#  'exam',
#  'pan',
#  'abs',
#  'jilu',
#  'shu',
#  'shang',
#  'dy',
#  'peek',
#  'xx',
#  'init',
#  'link',
#  'use',
#  'fen',
#  'counter',
#  'merge',
#  'rev',
#  'rec',
#  'stum',
#  'ld\\n',
#  'juli',
#  'isrunnian',
#  'words',
#  'book',
#  'isleapyear',
#  'na',
#  'man',
#  'comp',
#  'txia',
#  'start',
#  'all',
#  'fy',
#  'jiaohuan',
#  'dui',
#  'pp',
#  'zhao',
#  'qshang',
#  'spread',
#  'schsum',
#  'jh',
#  'juzhen',
#  'issushu',
#  'dfs',
#  'sex',
#  'fang',
#  'pa',
#  'cut',
#  'big',
#  'jisuan',
#  'bl',
#  'monkey',
#  'tolower',
#  'ci',
#  'answer',
#  'lenth',
#  'reserve',
#  'sentence',
#  'zuo',
#  'fanxu',
#  'now',
#  'begin',
#  'fan',
#  'guiling',
#  'go',
#  'hanshu',
#  'course',
#  'fbnq',
#  'fib',
#  'make',
#  'shift',
#  'ways',
#  'week',
#  'th',
#  'lc',
#  'tran',
#  'fild',
#  'iiii',
#  'third',
#  'best',
#  'xiaojian',
#  'islower',
#  'digui',
#  'same',
#  'bac',
#  'jian',
#  'tt',
#  'zero',
#  'kk',
#  'single',
#  'cha',
#  "'",
#  'cc',
#  'paidui',
#  'sscanf',
#  'indata',
#  'even',
#  'hou',
#  'after',
#  'freq',
#  'isalnum',
#  'letter',
#  'putout',
#  'queen',
#  'strncmp',
#  'tong',
#  'old',
#  'devide',
#  'strncat',
#  'jd',
#  'fgets',
#  'op',
#  'ansn',
#  'dist',
#  'sch',
#  'qiwange',
#  'xiao',
#  'process',
#  'ct',
#  'tbyte',
#  'huan',
#  'inv',
#  'weilen',
#  'cmovge',
#  'aut',
#  'operate',
#  'dst',
#  'maxn',
#  'level',
#  'fanzhi',
#  'sq',
#  'yeari',
#  'square',
#  'xb',
#  'show',
#  'ddd',
#  'strin',
#  'ord',
#  'yushu',
#  'sprintf',
#  'abc',
#  'clear',
#  'linelen',
#  'gap',
#  'fei',
#  'bubblesort',
#  'high',
#  'iiiii',
#  'beichu',
#  'cwde',
#  'cache',
#  'vis',
#  'before',
#  'yinshu',
#  'dt',
#  'qwdm',
#  'yes',
#  'substr',
#  'right',
#  'months',
#  'multiply',
#  'form',
#  'bacteria',
#  'fuck',
#  'sj',
#  'isupper',
#  'prt',
#  'poi',
#  'bijiao',
#  'cx',
#  'ou',
#  'low',
#  'ab',
#  'tm',
#  'yaolen',
#  'fj',
#  'yu',
#  'common',
#  'seq',
#  'flight',
#  'back',
#  'step',
#  'moun',
#  'tjdm',
#  'va',
#  'matrixx',
#  'val',
#  'record',
#  'cheng',
#  'men',
#  'derta',
#  'group',
#  'rr',
#  'changdu',
#  'minn',
#  'd/',
#  'dd',
#  'down',
#  'fight',
#  'd\\nz',
#  'd\\ns',
#  'd\\nq',
#  'nixu',
#  'findmax',
#  'feof',
#  'djt',
#  'qx',
#  'tmpl',
#  'xiaoshi',
#  'copy',
#  'pri',
#  'ff',
#  'cmovle',
#  'two',
#  'duqu',
#  'remain',
#  'cen',
#  'qiwangs',
#  'kh',
#  'cell',
#  'circle',
#  'pe',
#  'zhuan',
#  'bn',
#  'odd',
#  'pipei',
#  'chu',
#  'auth',
#  'bec',
#  'ave',
#  'wei',
#  'replacement',
#  'display',
#  'wang',
#  'tianjis',
#  'andian',
#  'minus',
#  'ming',
#  'wusi',
#  'score',
#  'ill',
#  'height',
#  'suan',
#  'kid',
#  'fucomip',
#  'left',
#  'tshang',
#  'qiw',
#  'isspace',
#  'team',
#  'can',
#  'sr',
#  'sa',
#  'lencount',
#  'eq',
#  'place',
#  'xa',
#  'msize',
#  'fsize',
#  'average',
#  'checki',
#  'mark',
#  'putin',
#  'coutnoneg',
#  'sca',
#  'thorse',
#  'qhorse',
#  'known',
#  'fb',
#  'connect',
#  'countday',
#  'nian',
#  'sta',
#  'xibu',
#  'fangcha',
#  'set',
#  'used',
#  'yuan',
#  'ppow',
#  'per',
#  'lans',
#  'ctt',
#  'shanchu',
#  'chr',
#  'leapyear',
#  'trail',
#  'li',
#  'choose',
#  'putstr',
#  'qt',
#  'peidui',
#  'inda',
#  'fact',
#  'tianshu',
#  'fre',
#  'empty',
#  'zheng',
#  'type',
#  'ma',
#  'mk',
#  'rn',
#  'checkprime',
#  'fsubp',
#  'doit',
#  'tries',
#  'putapple',
#  'du',
#  'fscanf',
#  'yuanshi',
#  'medium',
#  'together',
#  'mizhi',
#  'fmax',
#  'checkbegin',
#  'substring',
#  'pure',
#  'sc',
#  'ex',
#  'ishuiwen',
#  'yue',
#  'zhuanhuan',
#  'jiange',
#  'oushu',
#  'numfemale',
#  'jw',
#  'assertions',
#  'pay',
#  'ok',
#  'ai',
#  'tr',
#  'woman',
#  'list',
#  'sang',
#  'shulie',
#  'method',
#  'numb',
#  'fff',
#  'feibo',
#  'leg',
#  'pg',
#  'look',
#  'leapy',
#  'fflush',
#  'shisushu',
#  'bo',
#  'fibo',
#  '.f',
#  'fldz',
#  'qian',
#  'zl',
#  'boolean',
#  'sgn',
#  'tar',
#  'faddp',
#  'tag',
#  'xqj',
#  'ln',
#  'daoxu',
#  'zuozhe',
#  'varieties',
#  'angle',
#  'key',
#  'qxia',
#  'ysf',
#  'ppatient',
#  'cntf',
#  'cifang',
#  'bianli',
#  'hb',
#  'limit',
#  'precision',
#  'pr',
#  'xijun',
#  'huiwenshu',
#  'children',
#  'replace',
#  'mi',
#  'wine',
#  'fac',
#  'd.',
#  'prin',
#  'coutt',
#  'dg',
#  'next',
#  'blen',
#  'seven',
#  'ppp',
#  'baifang',
#  'imim',
#  'nf',
#  'inverse',
#  'flu',
#  'sb',
#  'increase',
#  'daodan',
#  'ano',
#  'germs',
#  'leapyearmonth',
#  'ju',
#  'former',
#  'author',
#  'istore',
#  'yeariiiii',
#  'speed',
#  'leta',
#  'letb',
#  'sums',
#  'jud',
#  'fuhao',
#  'tp',
#  'decide',
#  'qmg',
#  'full',
#  'hour',
#  'maxright',
#  'yy',
#  'findday',
#  'operation',
#  'banji',
#  'buf',
#  'remove',
#  'swi',
#  'origin',
#  'findlen',
#  'outputdata',
#  'monthday',
#  'rui',
#  'ba',
#  'maxlen',
#  'breed',
#  'bracket',
#  'lena',
#  'gg',
#  'nummale',
#  'bknown',
#  'judgeyear',
#  'need',
#  'sig',
#  'dao',
#  'dat',
#  'route',
#  'final',
#  'lastnumber',
#  'rearrange',
#  'gram',
#  'qh',
#  'equal',
#  'value',
#  'vb',
#  'cntm',
#  'sequence',
#  'minleft',
#  'pool',
#  'hh',
#  'commonyearmonth',
#  'stat',
#  '',
#  'direct',
#  'credit',
#  'countt',
#  'xueshen',
#  'tell',
#  'haha',
#  'femalecnt',
#  'mj',
#  'my',
#  'fibonacci',
#  'end',
#  'xj',
#  'zhongliu',
#  'alen',
#  'tianjie',
#  'zuida',
#  'houzi',
#  'nta',
#  'huanhang',
#  'toy',
#  'lanjie',
#  'getarray',
#  'jcount',
#  'jueduizhi',
#  'points',
#  'jiafa',
#  'de',
#  'filename',
#  'outcome',
#  'pre',
#  'fema',
#  'pro',
#  'ip',
#  'malecnt',
#  'hand',
#  'chengji',
#  'freopen',
#  'plu',
#  'noshowpos',
#  'lenofr',
#  'maximum',
#  'nn',
#  'hebin',
#  'primei',
#  'maopao',
#  'string',
#  'die',
#  'dir',
#  'mergesort',
#  'mincol',
#  'memory',
#  'showpos',
#  'erchashu',
#  'write',
#  'grow',
#  'sw',
#  'jie',
#  'jia',
#  'ee',
#  'routey',
#  'routex',
#  'xi',
#  'one',
#  'weekdays',
#  'firstout',
#  'outd',
#  'arrayv',
#  'take',
#  'destroy',
#  'normal',
#  'buffer',
#  'ccount',
#  'invert',
#  'geshu',
#  'modes',
#  'detc',
#  'lon',
#  'ffabs',
#  'bucket',
#  'cbw',
#  'legal',
#  'fab',
#  'small',
#  'tel',
#  'pailie',
#  'palin',
#  'amount',
#  'select',
#  'vi',
#  'dec',
#  'fr',
#  'fa',
#  'numa',
#  'fi',
#  'fk',
#  'grade',
#  'shuzi',
#  'reduce',
#  'nowlen',
#  'longtime',
#  'guess',
#  'ispr',
#  'highestpos',
#  'quicksort',
#  'setp',
#  'play',
#  'charu',
#  'exp',
#  'femail',
#  'printarray',
#  'totalmember',
#  'po',
#  'kuohao',
#  'jianli',
#  'oho',
#  'cul',
#  'couple']

# %%
reverse_dictionary
# Out:
# {0: 'UNK',
#  1: '$',
#  2: ',',
#  3: 'mov',
#  4: '+',
#  5: '[',
#  6: ']',
#  7: 'rbp',
#  8: 'eax',
#  9: 'var',
#  10: 'rax',
#  11: ':',
#  12: 'add',
#  13: 'loc',
#  14: 'rdx',
#  15: 'edx',
#  16: 'short',
#  17: 'cmp',
#  18: 'call',
#  19: '<',
#  20: 'std',
#  21: 'char',
#  22: '*',
#  23: 'lea',
#  24: 'cdqe',
#  25: '>',
#  26: 'sub',
#  27: 'jmp',
#  28: 'offset',
#  29: 'edi',
#  30: 'rcx',
#  31: 'ecx',
#  32: 'shl',
#  33: 'movsxd',
#  34: 'rsi',
#  35: ')',
#  36: '(',
#  37: 'esi',
#  38: 'ostream',
#  39: 'rdi',
#  40: 's',
#  41: 'al',
#  42: 'rsp',
#  43: '&',
#  44: 'jz',
#  45: 'traits',
#  46: 'operator',
#  47: 'movzx',
#  48: 'jnz',
#  49: 'xor',
#  50: 'fs',
#  51: 'movsd',
#  52: 'jge',
#  53: 'int',
#  54: 'imul',
#  55: 'push',
#  56: 'jg',
#  57: 'jle',
#  58: 'ptr',
#  59: 'sar',
#  60: 'printf',
#  61: 'test',
#  62: 'scanf',
#  63: 'basic',
#  64: 'ds',
#  65: 'retn',
#  66: 'format',
#  67: 'chk',
#  68: 'stack',
#  69: 'fail',
#  70: 'leave',
#  71: 'locret',
#  72: 'rbx',
#  73: 'cs',
#  74: 'istream',
#  75: 'byte',
#  76: 'd',
#  77: 'c',
#  78: 'movss',
#  79: 'pxor',
#  80: 'qword',
#  81: 'dword',
#  82: 'movsx',
#  83: 'const',
#  84: 'pop',
#  85: 'jl',
#  86: 'endl',
#  87: 'strlen',
#  88: 'nop',
#  89: 'dl',
#  90: 'putchar',
#  91: 'puts',
#  92: 'mulsd',
#  93: 'movapd',
#  94: 'shr',
#  95: 'unk',
#  96: 'ucomisd',
#  97: 'ebx',
#  98: 'subsd',
#  99: 'divsd',
#  100: 'addsd',
#  101: 'rep',
#  102: 'stosq',
#  103: 'a',
#  104: 'jbe',
#  105: 'x',
#  106: 'gets',
#  107: 'edata',
#  108: 'n',
#  109: 'js',
#  110: 'src',
#  111: 'and',
#  112: 'idiv',
#  113: 'cdq',
#  114: 'base',
#  115: 'getchar',
#  116: 'sqrt',
#  117: 'dest',
#  118: 'double',
#  119: 'void',
#  120: 'setz',
#  121: 'setnz',
#  122: 'i',
#  123: 'memset',
#  124: 'ios',
#  125: 'setnle',
#  126: 'long',
#  127: 'jb',
#  128: 'size',
#  129: 'ucomiss',
#  130: 'neg',
#  131: 'jnb',
#  132: 'div',
#  133: 'getline',
#  134: 'cl',
#  135: 'malloc',
#  136: 'strcmp',
#  137: 'strcpy',
#  138: 'f',
#  139: 'jp',
#  140: 'ja',
#  141: 'mulss',
#  142: 'subss',
#  143: 'addss',
#  144: 'b',
#  145: 'lf',
#  146: 'get',
#  147: 'd\\n',
#  148: 'movq',
#  149: 'xorpd',
#  150: 'mul',
#  151: 'asc',
#  152: 'j',
#  153: 'y',
#  154: 'divss',
#  155: 'movaps',
#  156: 'pow',
#  157: 'm',
#  158: 'float',
#  159: 'k',
#  160: 'jns',
#  161: 'off',
#  162: 'setprecision',
#  163: 'fixed',
#  164: 'num',
#  165: 'cos',
#  166: 'ax',
#  167: 'cqo',
#  168: 'nmemb',
#  169: 'nptr',
#  170: 'c=',
#  171: 'p',
#  172: 'sum',
#  173: 'main',
#  174: 'andpd',
#  175: 'free',
#  176: 's\\n',
#  177: 't',
#  178: 'qsort',
#  179: 'compar',
#  180: 'cmovs',
#  181: 'str',
#  182: 'reverse',
#  183: 'sort',
#  184: 'l',
#  185: 'xorps',
#  186: 'setl',
#  187: 'setnb',
#  188: 'max',
#  189: 'sushu',
#  190: 'd=',
#  191: 'haystack',
#  192: 'or',
#  193: 'stu',
#  194: 'temp',
#  195: '-',
#  196: 'q',
#  197: '=',
#  198: 'setnbe',
#  199: 'strcat',
#  200: 'g',
#  201: 'len',
#  202: 'judge',
#  203: 'word',
#  204: 'ii',
#  205: 'needle',
#  206: 'change',
#  207: 'ld',
#  208: 'prime',
#  209: 'c\\n',
#  210: 'iii',
#  211: 'sil',
#  212: 'ans',
#  213: 'print',
#  214: 'andps',
#  215: 'atoi',
#  216: 'setle',
#  217: 'check',
#  218: 'r',
#  219: 'lf\\n',
#  220: 'min',
#  221: 'huiwen',
#  222: 'paixu',
#  223: 'setnl',
#  224: 'swap',
#  225: 'e',
#  226: 'count',
#  227: 'st',
#  228: 'input',
#  229: 'total',
#  230: 'array',
#  231: 'calloc',
#  232: 'strncpy',
#  233: 'h',
#  234: 'dil',
#  235: 'flag',
#  236: 'w',
#  237: 'data',
#  238: 'z',
#  239: 'days',
#  240: 'su',
#  241: 'row',
#  242: 'student',
#  243: 'node',
#  244: 'year',
#  245: 'leap',
#  246: 'day',
#  247: 'result',
#  248: 'apple',
#  249: 'dis',
#  250: 'panduan',
#  251: 'strstr',
#  252: 'col',
#  253: 'floor',
#  254: 'fun',
#  255: 'output',
#  256: 'uint',
#  257: 'creat',
#  258: 'dx',
#  259: 'move',
#  260: 'sz',
#  261: 'number',
#  262: 'board',
#  263: 'line',
#  264: 'length',
#  265: 'find',
#  266: 'out',
#  267: 'read',
#  268: 'match',
#  269: 'cal',
#  270: 'not',
#  271: 'tmp',
#  272: 'movd',
#  273: 'in',
#  274: 'queue',
#  275: 'dp',
#  276: 'isprime',
#  277: 'ss',
#  278: 'boy',
#  279: 'o',
#  280: 'cmovnz',
#  281: 'shuchu',
#  282: 'month',
#  283: 'tian',
#  284: 'order',
#  285: 'run',
#  286: 'search',
#  287: 'setnp',
#  288: 'stream',
#  289: 'combine',
#  290: 'cnt',
#  291: 'bubble',
#  292: 'atof',
#  293: 'work',
#  294: 'first',
#  295: 'shuru',
#  296: 'head',
#  297: 'map',
#  298: 'pd',
#  299: 'function',
#  300: 'hui',
#  301: 'u',
#  302: 'person',
#  303: 'toupper',
#  304: 'repne',
#  305: 'date',
#  306: 'scasb',
#  307: 'put',
#  308: 'trans',
#  309: 'area',
#  310: 'room',
#  311: 'movsq',
#  312: 'fenjie',
#  313: 'mat',
#  314: 'compare',
#  315: 'point',
#  316: 'hebing',
#  317: 'money',
#  318: 'res',
#  319: 'isalpha',
#  320: 'nm',
#  321: 'tj',
#  322: 'ld=',
#  323: 'tianji',
#  324: 'jiaogu',
#  325: 'com',
#  326: 'girl',
#  327: 'runnian',
#  328: 'matrix',
#  329: 'qiwang',
#  330: 'an',
#  331: 'v',
#  332: 'dijitian',
#  333: 'la',
#  334: 'exchange',
#  335: 'qw',
#  336: 'power',
#  337: 'female',
#  338: 'mon',
#  339: 'zhishu',
#  340: 'func',
#  341: 'turn',
#  342: 'exit',
#  343: 'status',
#  344: 'times',
#  345: 'divide',
#  346: 'fld',
#  347: 'scan',
#  348: 'is',
#  349: 'male',
#  350: 'log',
#  351: 'fmod',
#  352: 'strchr',
#  353: 'fstp',
#  354: 'pai',
#  355: 'del',
#  356: 'insert',
#  357: 'memcpy',
#  358: 'rank',
#  359: 'ulong',
#  360: 'f\\n',
#  361: 'sen',
#  362: 'delim',
#  363: 'aa',
#  364: 'create',
#  365: 'arrange',
#  366: 'strtok',
#  367: 'calc',
#  368: 'tot',
#  369: 'child',
#  370: 'mx',
#  371: 's=',
#  372: 'solve',
#  373: 'win',
#  374: 'lb',
#  375: 'qq',
#  376: 'qi',
#  377: 'distance',
#  378: 'sign',
#  379: 'to',
#  380: 'convert',
#  381: 'state',
#  382: 'ioinit',
#  383: 'shuzu',
#  384: 'factor',
#  385: 'he',
#  386: 're',
#  387: 'im',
#  388: 'up',
#  389: 'ji',
#  390: 'tem',
#  391: 'king',
#  392: 'chang',
#  393: 'stud',
#  394: 'px',
#  395: 'hang',
#  396: 'of',
#  397: 'arr',
#  398: 'arg',
#  399: 'bb',
#  400: 'calculate',
#  401: 'name',
#  402: 'pat',
#  403: 'aaa',
#  404: 'grids',
#  405: 'hw',
#  406: 'ceil',
#  407: 'deal',
#  408: 'people',
#  409: 'way',
#  410: 'pos',
#  411: 'jishu',
#  412: 'ys',
#  413: 'lie',
#  414: 'ignore',
#  415: 'patient',
#  416: 'zhi',
#  417: 'zh',
#  418: 'from',
#  419: 'ren',
#  420: 'zfc',
#  421: 'ch',
#  422: 'know',
#  423: 'second',
#  424: 'tree',
#  425: 'mianji',
#  426: 'mo',
#  427: 'zimu',
#  428: 'qj',
#  429: 'exam',
#  430: 'pan',
#  431: 'abs',
#  432: 'jilu',
#  433: 'shu',
#  434: 'shang',
#  435: 'dy',
#  436: 'peek',
#  437: 'xx',
#  438: 'init',
#  439: 'link',
#  440: 'use',
#  441: 'fen',
#  442: 'counter',
#  443: 'merge',
#  444: 'rev',
#  445: 'rec',
#  446: 'stum',
#  447: 'ld\\n',
#  448: 'juli',
#  449: 'isrunnian',
#  450: 'words',
#  451: 'book',
#  452: 'isleapyear',
#  453: 'na',
#  454: 'man',
#  455: 'comp',
#  456: 'txia',
#  457: 'start',
#  458: 'all',
#  459: 'fy',
#  460: 'jiaohuan',
#  461: 'dui',
#  462: 'pp',
#  463: 'zhao',
#  464: 'qshang',
#  465: 'spread',
#  466: 'schsum',
#  467: 'jh',
#  468: 'juzhen',
#  469: 'issushu',
#  470: 'dfs',
#  471: 'sex',
#  472: 'fang',
#  473: 'pa',
#  474: 'cut',
#  475: 'big',
#  476: 'jisuan',
#  477: 'bl',
#  478: 'monkey',
#  479: 'tolower',
#  480: 'ci',
#  481: 'answer',
#  482: 'lenth',
#  483: 'reserve',
#  484: 'sentence',
#  485: 'zuo',
#  486: 'fanxu',
#  487: 'now',
#  488: 'begin',
#  489: 'fan',
#  490: 'guiling',
#  491: 'go',
#  492: 'hanshu',
#  493: 'course',
#  494: 'fbnq',
#  495: 'fib',
#  496: 'make',
#  497: 'shift',
#  498: 'ways',
#  499: 'week',
#  500: 'th',
#  501: 'lc',
#  502: 'tran',
#  503: 'fild',
#  504: 'iiii',
#  505: 'third',
#  506: 'best',
#  507: 'xiaojian',
#  508: 'islower',
#  509: 'digui',
#  510: 'same',
#  511: 'bac',
#  512: 'jian',
#  513: 'tt',
#  514: 'zero',
#  515: 'kk',
#  516: 'single',
#  517: 'cha',
#  518: "'",
#  519: 'cc',
#  520: 'paidui',
#  521: 'sscanf',
#  522: 'indata',
#  523: 'even',
#  524: 'hou',
#  525: 'after',
#  526: 'freq',
#  527: 'isalnum',
#  528: 'letter',
#  529: 'putout',
#  530: 'queen',
#  531: 'strncmp',
#  532: 'tong',
#  533: 'old',
#  534: 'devide',
#  535: 'strncat',
#  536: 'jd',
#  537: 'fgets',
#  538: 'op',
#  539: 'ansn',
#  540: 'dist',
#  541: 'sch',
#  542: 'qiwange',
#  543: 'xiao',
#  544: 'process',
#  545: 'ct',
#  546: 'tbyte',
#  547: 'huan',
#  548: 'inv',
#  549: 'weilen',
#  550: 'cmovge',
#  551: 'aut',
#  552: 'operate',
#  553: 'dst',
#  554: 'maxn',
#  555: 'level',
#  556: 'fanzhi',
#  557: 'sq',
#  558: 'yeari',
#  559: 'square',
#  560: 'xb',
#  561: 'show',
#  562: 'ddd',
#  563: 'strin',
#  564: 'ord',
#  565: 'yushu',
#  566: 'sprintf',
#  567: 'abc',
#  568: 'clear',
#  569: 'linelen',
#  570: 'gap',
#  571: 'fei',
#  572: 'bubblesort',
#  573: 'high',
#  574: 'iiiii',
#  575: 'beichu',
#  576: 'cwde',
#  577: 'cache',
#  578: 'vis',
#  579: 'before',
#  580: 'yinshu',
#  581: 'dt',
#  582: 'qwdm',
#  583: 'yes',
#  584: 'substr',
#  585: 'right',
#  586: 'months',
#  587: 'multiply',
#  588: 'form',
#  589: 'bacteria',
#  590: 'fuck',
#  591: 'sj',
#  592: 'isupper',
#  593: 'prt',
#  594: 'poi',
#  595: 'bijiao',
#  596: 'cx',
#  597: 'ou',
#  598: 'low',
#  599: 'ab',
#  600: 'tm',
#  601: 'yaolen',
#  602: 'fj',
#  603: 'yu',
#  604: 'common',
#  605: 'seq',
#  606: 'flight',
#  607: 'back',
#  608: 'step',
#  609: 'moun',
#  610: 'tjdm',
#  611: 'va',
#  612: 'matrixx',
#  613: 'val',
#  614: 'record',
#  615: 'cheng',
#  616: 'men',
#  617: 'derta',
#  618: 'group',
#  619: 'rr',
#  620: 'changdu',
#  621: 'minn',
#  622: 'd/',
#  623: 'dd',
#  624: 'down',
#  625: 'fight',
#  626: 'd\\nz',
#  627: 'd\\ns',
#  628: 'd\\nq',
#  629: 'nixu',
#  630: 'findmax',
#  631: 'feof',
#  632: 'djt',
#  633: 'qx',
#  634: 'tmpl',
#  635: 'xiaoshi',
#  636: 'copy',
#  637: 'pri',
#  638: 'ff',
#  639: 'cmovle',
#  640: 'two',
#  641: 'duqu',
#  642: 'remain',
#  643: 'cen',
#  644: 'qiwangs',
#  645: 'kh',
#  646: 'cell',
#  647: 'circle',
#  648: 'pe',
#  649: 'zhuan',
#  650: 'bn',
#  651: 'odd',
#  652: 'pipei',
#  653: 'chu',
#  654: 'auth',
#  655: 'bec',
#  656: 'ave',
#  657: 'wei',
#  658: 'replacement',
#  659: 'display',
#  660: 'wang',
#  661: 'tianjis',
#  662: 'andian',
#  663: 'minus',
#  664: 'ming',
#  665: 'wusi',
#  666: 'score',
#  667: 'ill',
#  668: 'height',
#  669: 'suan',
#  670: 'kid',
#  671: 'fucomip',
#  672: 'left',
#  673: 'tshang',
#  674: 'qiw',
#  675: 'isspace',
#  676: 'team',
#  677: 'can',
#  678: 'sr',
#  679: 'sa',
#  680: 'lencount',
#  681: 'eq',
#  682: 'place',
#  683: 'xa',
#  684: 'msize',
#  685: 'fsize',
#  686: 'average',
#  687: 'checki',
#  688: 'mark',
#  689: 'putin',
#  690: 'coutnoneg',
#  691: 'sca',
#  692: 'thorse',
#  693: 'qhorse',
#  694: 'known',
#  695: 'fb',
#  696: 'connect',
#  697: 'countday',
#  698: 'nian',
#  699: 'sta',
#  700: 'xibu',
#  701: 'fangcha',
#  702: 'set',
#  703: 'used',
#  704: 'yuan',
#  705: 'ppow',
#  706: 'per',
#  707: 'lans',
#  708: 'ctt',
#  709: 'shanchu',
#  710: 'chr',
#  711: 'leapyear',
#  712: 'trail',
#  713: 'li',
#  714: 'choose',
#  715: 'putstr',
#  716: 'qt',
#  717: 'peidui',
#  718: 'inda',
#  719: 'fact',
#  720: 'tianshu',
#  721: 'fre',
#  722: 'empty',
#  723: 'zheng',
#  724: 'type',
#  725: 'ma',
#  726: 'mk',
#  727: 'rn',
#  728: 'checkprime',
#  729: 'fsubp',
#  730: 'doit',
#  731: 'tries',
#  732: 'putapple',
#  733: 'du',
#  734: 'fscanf',
#  735: 'yuanshi',
#  736: 'medium',
#  737: 'together',
#  738: 'mizhi',
#  739: 'fmax',
#  740: 'checkbegin',
#  741: 'substring',
#  742: 'pure',
#  743: 'sc',
#  744: 'ex',
#  745: 'ishuiwen',
#  746: 'yue',
#  747: 'zhuanhuan',
#  748: 'jiange',
#  749: 'oushu',
#  750: 'numfemale',
#  751: 'jw',
#  752: 'assertions',
#  753: 'pay',
#  754: 'ok',
#  755: 'ai',
#  756: 'tr',
#  757: 'woman',
#  758: 'list',
#  759: 'sang',
#  760: 'shulie',
#  761: 'method',
#  762: 'numb',
#  763: 'fff',
#  764: 'feibo',
#  765: 'leg',
#  766: 'pg',
#  767: 'look',
#  768: 'leapy',
#  769: 'fflush',
#  770: 'shisushu',
#  771: 'bo',
#  772: 'fibo',
#  773: '.f',
#  774: 'fldz',
#  775: 'qian',
#  776: 'zl',
#  777: 'boolean',
#  778: 'sgn',
#  779: 'tar',
#  780: 'faddp',
#  781: 'tag',
#  782: 'xqj',
#  783: 'ln',
#  784: 'daoxu',
#  785: 'zuozhe',
#  786: 'varieties',
#  787: 'angle',
#  788: 'key',
#  789: 'qxia',
#  790: 'ysf',
#  791: 'ppatient',
#  792: 'cntf',
#  793: 'cifang',
#  794: 'bianli',
#  795: 'hb',
#  796: 'limit',
#  797: 'precision',
#  798: 'pr',
#  799: 'xijun',
#  800: 'huiwenshu',
#  801: 'children',
#  802: 'replace',
#  803: 'mi',
#  804: 'wine',
#  805: 'fac',
#  806: 'd.',
#  807: 'prin',
#  808: 'coutt',
#  809: 'dg',
#  810: 'next',
#  811: 'blen',
#  812: 'seven',
#  813: 'ppp',
#  814: 'baifang',
#  815: 'imim',
#  816: 'nf',
#  817: 'inverse',
#  818: 'flu',
#  819: 'sb',
#  820: 'increase',
#  821: 'daodan',
#  822: 'ano',
#  823: 'germs',
#  824: 'leapyearmonth',
#  825: 'ju',
#  826: 'former',
#  827: 'author',
#  828: 'istore',
#  829: 'yeariiiii',
#  830: 'speed',
#  831: 'leta',
#  832: 'letb',
#  833: 'sums',
#  834: 'jud',
#  835: 'fuhao',
#  836: 'tp',
#  837: 'decide',
#  838: 'qmg',
#  839: 'full',
#  840: 'hour',
#  841: 'maxright',
#  842: 'yy',
#  843: 'findday',
#  844: 'operation',
#  845: 'banji',
#  846: 'buf',
#  847: 'remove',
#  848: 'swi',
#  849: 'origin',
#  850: 'findlen',
#  851: 'outputdata',
#  852: 'monthday',
#  853: 'rui',
#  854: 'ba',
#  855: 'maxlen',
#  856: 'breed',
#  857: 'bracket',
#  858: 'lena',
#  859: 'gg',
#  860: 'nummale',
#  861: 'bknown',
#  862: 'judgeyear',
#  863: 'need',
#  864: 'sig',
#  865: 'dao',
#  866: 'dat',
#  867: 'route',
#  868: 'final',
#  869: 'lastnumber',
#  870: 'rearrange',
#  871: 'gram',
#  872: 'qh',
#  873: 'equal',
#  874: 'value',
#  875: 'vb',
#  876: 'cntm',
#  877: 'sequence',
#  878: 'minleft',
#  879: 'pool',
#  880: 'hh',
#  881: 'commonyearmonth',
#  882: 'stat',
#  883: '',
#  884: 'direct',
#  885: 'credit',
#  886: 'countt',
#  887: 'xueshen',
#  888: 'tell',
#  889: 'haha',
#  890: 'femalecnt',
#  891: 'mj',
#  892: 'my',
#  893: 'fibonacci',
#  894: 'end',
#  895: 'xj',
#  896: 'zhongliu',
#  897: 'alen',
#  898: 'tianjie',
#  899: 'zuida',
#  900: 'houzi',
#  901: 'nta',
#  902: 'huanhang',
#  903: 'toy',
#  904: 'lanjie',
#  905: 'getarray',
#  906: 'jcount',
#  907: 'jueduizhi',
#  908: 'points',
#  909: 'jiafa',
#  910: 'de',
#  911: 'filename',
#  912: 'outcome',
#  913: 'pre',
#  914: 'fema',
#  915: 'pro',
#  916: 'ip',
#  917: 'malecnt',
#  918: 'hand',
#  919: 'chengji',
#  920: 'freopen',
#  921: 'plu',
#  922: 'noshowpos',
#  923: 'lenofr',
#  924: 'maximum',
#  925: 'nn',
#  926: 'hebin',
#  927: 'primei',
#  928: 'maopao',
#  929: 'string',
#  930: 'die',
#  931: 'dir',
#  932: 'mergesort',
#  933: 'mincol',
#  934: 'memory',
#  935: 'showpos',
#  936: 'erchashu',
#  937: 'write',
#  938: 'grow',
#  939: 'sw',
#  940: 'jie',
#  941: 'jia',
#  942: 'ee',
#  943: 'routey',
#  944: 'routex',
#  945: 'xi',
#  946: 'one',
#  947: 'weekdays',
#  948: 'firstout',
#  949: 'outd',
#  950: 'arrayv',
#  951: 'take',
#  952: 'destroy',
#  953: 'normal',
#  954: 'buffer',
#  955: 'ccount',
#  956: 'invert',
#  957: 'geshu',
#  958: 'modes',
#  959: 'detc',
#  960: 'lon',
#  961: 'ffabs',
#  962: 'bucket',
#  963: 'cbw',
#  964: 'legal',
#  965: 'fab',
#  966: 'small',
#  967: 'tel',
#  968: 'pailie',
#  969: 'palin',
#  970: 'amount',
#  971: 'select',
#  972: 'vi',
#  973: 'dec',
#  974: 'fr',
#  975: 'fa',
#  976: 'numa',
#  977: 'fi',
#  978: 'fk',
#  979: 'grade',
#  980: 'shuzi',
#  981: 'reduce',
#  982: 'nowlen',
#  983: 'longtime',
#  984: 'guess',
#  985: 'ispr',
#  986: 'highestpos',
#  987: 'quicksort',
#  988: 'setp',
#  989: 'play',
#  990: 'charu',
#  991: 'exp',
#  992: 'femail',
#  993: 'printarray',
#  994: 'totalmember',
#  995: 'po',
#  996: 'kuohao',
#  997: 'jianli',
#  998: 'oho',
#  999: 'cul',
#  ...}
